# %%
import os
import time
from datetime import date, datetime

import geopandas as gpd
import googlemaps
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from dotenv import load_dotenv
from shapely.geometry import Point
from sqlalchemy import create_engine
import time

from mods import gmap

load_dotenv()
# Out:
# True

# %%
# E_取得gml檔案，並轉換成gdf物件
folder = r"C:\Users\add41\Documents\Data_Engineer\Project\example_data"
file = "COUNTY_MOI_1140318.gml"
target = os.path.join(folder, file)

gdf = gpd.read_file(target)

# 列出目標縣市（台北市被包含在新北市中），並設定英文代號
today = date.today().strftime("%Y/%m/%d")
target_city = ["新北市", "桃園市", "臺中市", "臺南市", "高雄市"]
city_eng = ["TPE", "TYU", "TCH", "TNA", "KSH"]
target_index = []
city_dict = {
    "新北市":"TPE",
    "桃園市":"TYU",
    "臺中市":"TCH",
    "臺南市":"TNA",
    "高雄市":"KSH"
}

# 將目標縣市的索引加入列表中
for city in target_city:
    target_index.append(gdf[gdf["名稱"] == city].index)

# %%
def gmap_nearby_search(key, lat, lon, radius, keyword):
    """提供api_key，經緯度和關鍵字，回傳搜尋結果的列表，資訊包括名稱、place_id和地址"""
    # 使用gmap連線並搜尋，取得搜尋結果
    gmaps = googlemaps.Client(key=key)
    search_result = gmaps.places_nearby(location=(lat, lon), radius=radius, keyword=keyword)
    result = search_result.get("results", [])
    page = 1
    
    # 取出第一頁搜尋結果的名稱、place_id和地址，存成字典後加入list
    result_data = []
    for place in result:
        place_dict = {
            "name":place.get("name", None),
            "place_id":place.get("place_id", None),
            "buss_status":place.get("business_status", None)
        }
        result_data.append(place_dict)


    # 進入迴圈判斷是否有下一頁，如果沒有直接停止，若有則迴圈
    time.sleep(2.5)
    next_page = search_result.get("next_page_token", None)
    
    while next_page:
        page += 1
        max_tries = 3
        for tries in range(1, max_tries+1):
            try:
                print(f"正在取得第{page}頁資訊...")
                time.sleep(2.5)
                next_page_search = gmaps.places_nearby(page_token=next_page)
                next_page_result = next_page_search.get("results", [])
                for place in next_page_result:
                    place_dict = {
                        "name":place.get("name", None),
                        "place_id":place.get("place_id", None),
                        "buss_status":place.get("business_status", None)
                    }
                    result_data.append(place_dict)
                time.sleep(2.5)
                next_page = next_page_search.get("next_page_token", None)
                break

            except Exception as e:
                if tries >= max_tries:
                    print("已達最大嘗試次數")
                    next_page = None
                    break
                else:
                    print(f"第{tries}次嘗試失敗：{e}\n等待3秒後重試...")
                    time.sleep(3)
    
    return result_data

# %%
## E_透過gmap API遍尋六都資料

# 定義關鍵字列表和對應的英文名 # "寵物美容", 
keyword_list = ["寵物餐廳", "寵物用品"]
keyword_dict = {
    "寵物美容":"salon",
    "寵物餐廳":"restaurant",
    "寵物用品":"supplies"
}

# 根據存取的索引列表去取出每一個縣市的多邊形資料
for keyword in keyword_list:
    metadate = []
    for idx in target_index:
        name = city_dict[gdf.loc[idx]["名稱"].values[0]]
        city_geo_data = gdf.loc[idx].geometry.values[0]

        # 取得四極點
        min_x, min_y, max_x, max_y = city_geo_data.bounds

        # 設定搜尋半徑及步長
        radius_m = 3000
        step_m = 3000

        # 將距離換算成經緯度
        lat_step = step_m / 111000
        lon_step = step_m / (111000 * np.cos(np.radians((min_y + max_y) / 2)))

        # 產生在範圍內的所有座標點
        lat_point = np.arange(min_y, max_y, lat_step)
        lon_point = np.arange(min_x, max_x, lon_step)

        print(f"開始搜尋{name}的{keyword}資料")
        print(f"lat個數：{len(lat_point)}")
        print(f"lon個數：{len(lon_point)}")

        # 將所有取得的經緯度組合成所有座標點，並形成一個list
        points = []

        for lat_p in lat_point:
            for lon_p in lon_point:
                loc = (lon_p, lat_p)
                points.append(loc)

        print(f"座標點個數：{len(points)}")

        # 開始進行gmap資料爬取
        data = []
        key = os.environ.get("GMAP_KEY5")
        count = 1

        for loc in points:
            loc_p = Point(loc[0], loc[1])

            if city_geo_data.contains(loc_p):
                lat = loc[1]
                lon = loc[0]
                result_list = gmap.gmap_nearby_search(key=key, lat=lat, lon=lon, radius=radius_m, keyword=keyword)
                for i in result_list:
                    data.append(i)

                print(f"完成{name}的{keyword}的第{count}/{len(points)}個座標點（{round(float(loc[1]), 7)}, {round(float(loc[0]), 7)}）的搜尋，共有{len(result_list)}筆店家資料")
                count += 1
                time.sleep(1)

        city_metadata = {
            "city":name,
            "coord_count":count,
            "data_count":len(data),
            "type":keyword_dict[keyword],
            "update_date":today
        }
        metadate.append(city_metadata)
        print(f"完成{name}的{keyword}資料搜尋，總共搜尋{count}個座標點")

        # 將結果轉換成df並建立更新時間欄位
        df = pd.DataFrame(data=data)
        df["update_time"] = datetime.now().strftime("%Y/%m/%d %H:%M:%S")

        # 將檔案儲存為csv
        save = r"C:\Users\add41\Documents\Data_Engineer\Project\example_data\gmap_full_search"
        file_name = f"gmap_{keyword_dict[keyword]}_{name}.csv"
        save_path = os.path.join(save, file_name)
        df.to_csv(save_path, index=False)

        print(f"已完成{name}資料儲存")
        time.sleep(3)


    # E_儲存元數據報告
    username = os.getenv("MYSQL_USERNAME")
    password = os.getenv("MYSQL_PASSWORD")
    target_ip = os.getenv("MYSQL_IP")
    target_port = int(os.getenv("MYSQL_PORTT"))
    db_name = os.getenv("MYSQL_DB_NAME")

    engine = create_engine(f"mysql+pymysql://{username}:{password}@{target_ip}:{target_port}/{db_name}")

    sql = "SELECT * FROM gmap_record;"

    df_record = pd.read_sql(sql, engine)

    # 將本次報告與原有紀錄合併
    df_meta = pd.DataFrame(metadate)
    df_meta["type"] = keyword_dict[keyword]

    df_record = pd.concat([df_record, df_meta], ignore_index=True)
    df_record.drop_duplicates(keep="first", inplace=True)


    # 按照日期進行儲存
    today = date.today().strftime("%Y%m%d")

    meta_save = r"C:\Users\add41\Documents\Data_Engineer\Project\example_data\gmap_full_search"
    meta_name = f"{today}_{keyword_dict[keyword]}_record.csv"
    save_path = os.path.join(meta_save, meta_name)

    df_record.to_csv(save_path, index=False)
    df_record.to_sql(name="gmap_record", con=engine, index=False, if_exists="replace")
# Out:
# 開始搜尋TPE的寵物美容資料
# lat個數：20
# lon個數：21
# 座標點個數：420
# 完成TPE的寵物美容的第1個座標點（24.7047236, 121.4566253）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第2個座標點（24.7047236, 121.4914128）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第3個座標點（24.7047236, 121.5262002）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第4個座標點（24.7362552, 121.4566253）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第5個座標點（24.7362552, 121.4914128）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第6個座標點（24.7362552, 121.5262002）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第7個座標點（24.7362552, 121.5609876）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第8個座標點（24.7677867, 121.4566253）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第9個座標點（24.7677867, 121.4914128）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第10個座標點（24.7677867, 121.5262002）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第11個座標點（24.7677867, 121.5609876）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第12個座標點（24.7677867, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第13個座標點（24.7993182, 121.4566253）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第14個座標點（24.7993182, 121.4914128）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第15個座標點（24.7993182, 121.5262002）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第16個座標點（24.7993182, 121.5609876）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第17個座標點（24.7993182, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第18個座標點（24.8308498, 121.4218379）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第19個座標點（24.8308498, 121.4566253）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第20個座標點（24.8308498, 121.4914128）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第21個座標點（24.8308498, 121.5262002）的搜尋，共有1筆店家資料
# 完成TPE的寵物美容的第22個座標點（24.8308498, 121.5609876）的搜尋，共有1筆店家資料
# 完成TPE的寵物美容的第23個座標點（24.8308498, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第24個座標點（24.8308498, 121.6305625）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第25個座標點（24.8308498, 121.66535）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第26個座標點（24.8623813, 121.352263）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第27個座標點（24.8623813, 121.3870504）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第28個座標點（24.8623813, 121.4218379）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第29個座標點（24.8623813, 121.4566253）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第30個座標點（24.8623813, 121.4914128）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第31個座標點（24.8623813, 121.5262002）的搜尋，共有1筆店家資料
# 完成TPE的寵物美容的第32個座標點（24.8623813, 121.5609876）的搜尋，共有1筆店家資料
# 完成TPE的寵物美容的第33個座標點（24.8623813, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第34個座標點（24.8623813, 121.6305625）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第35個座標點（24.8623813, 121.66535）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第36個座標點（24.8623813, 121.7001374）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第37個座標點（24.8623813, 121.7349249）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第38個座標點（24.8939128, 121.352263）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第39個座標點（24.8939128, 121.3870504）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第40個座標點（24.8939128, 121.4218379）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第41個座標點（24.8939128, 121.4566253）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第42個座標點（24.8939128, 121.4914128）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第43個座標點（24.8939128, 121.5262002）的搜尋，共有1筆店家資料
# 完成TPE的寵物美容的第44個座標點（24.8939128, 121.5609876）的搜尋，共有1筆店家資料
# 完成TPE的寵物美容的第45個座標點（24.8939128, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第46個座標點（24.8939128, 121.6305625）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第47個座標點（24.8939128, 121.66535）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第48個座標點（24.8939128, 121.7001374）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第49個座標點（24.8939128, 121.7349249）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第50個座標點（24.8939128, 121.7697123）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第51個座標點（24.9254444, 121.352263）的搜尋，共有32筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第52個座標點（24.9254444, 121.3870504）的搜尋，共有28筆店家資料
# 完成TPE的寵物美容的第53個座標點（24.9254444, 121.4218379）的搜尋，共有3筆店家資料
# 完成TPE的寵物美容的第54個座標點（24.9254444, 121.4566253）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第55個座標點（24.9254444, 121.4914128）的搜尋，共有2筆店家資料
# 完成TPE的寵物美容的第56個座標點（24.9254444, 121.5262002）的搜尋，共有5筆店家資料
# 完成TPE的寵物美容的第57個座標點（24.9254444, 121.5609876）的搜尋，共有3筆店家資料
# 完成TPE的寵物美容的第58個座標點（24.9254444, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第59個座標點（24.9254444, 121.6305625）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第60個座標點（24.9254444, 121.66535）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第61個座標點（24.9254444, 121.7001374）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第62個座標點（24.9254444, 121.7349249）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第63個座標點（24.9254444, 121.7697123）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第64個座標點（24.9254444, 121.8044998）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第65個座標點（24.9254444, 121.8392872）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第66個座標點（24.9569759, 121.352263）的搜尋，共有32筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第67個座標點（24.9569759, 121.3870504）的搜尋，共有37筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第68個座標點（24.9569759, 121.4218379）的搜尋，共有28筆店家資料
# 完成TPE的寵物美容的第69個座標點（24.9569759, 121.4566253）的搜尋，共有17筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第70個座標點（24.9569759, 121.4914128）的搜尋，共有33筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第71個座標點（24.9569759, 121.5262002）的搜尋，共有35筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第72個座標點（24.9569759, 121.5609876）的搜尋，共有42筆店家資料
# 完成TPE的寵物美容的第73個座標點（24.9569759, 121.5957751）的搜尋，共有7筆店家資料
# 完成TPE的寵物美容的第74個座標點（24.9569759, 121.6305625）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第75個座標點（24.9569759, 121.66535）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第76個座標點（24.9569759, 121.7001374）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第77個座標點（24.9569759, 121.7349249）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第78個座標點（24.9569759, 121.7697123）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第79個座標點（24.9569759, 121.8044998）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第80個座標點（24.9569759, 121.8392872）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第81個座標點（24.9885074, 121.3870504）的搜尋，共有12筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第82個座標點（24.9885074, 121.4218379）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第83個座標點（24.9885074, 121.4566253）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第84個座標點（24.9885074, 121.4914128）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第85個座標點（24.9885074, 121.5262002）的搜尋，共有60筆店家資料
# 完成TPE的寵物美容的第86個座標點（24.9885074, 121.6305625）的搜尋，共有3筆店家資料
# 完成TPE的寵物美容的第87個座標點（24.9885074, 121.66535）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第88個座標點（24.9885074, 121.7001374）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第89個座標點（24.9885074, 121.7349249）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第90個座標點（24.9885074, 121.7697123）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第91個座標點（24.9885074, 121.8044998）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第92個座標點（24.9885074, 121.8392872）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第93個座標點（24.9885074, 121.8740746）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第94個座標點（24.9885074, 121.9088621）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第95個座標點（24.9885074, 121.9436495）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第96個座標點（25.020039, 121.4218379）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第97個座標點（25.020039, 121.4566253）的搜尋，共有60筆店家資料
# 完成TPE的寵物美容的第98個座標點（25.020039, 121.6305625）的搜尋，共有7筆店家資料
# 完成TPE的寵物美容的第99個座標點（25.020039, 121.66535）的搜尋，共有1筆店家資料
# 完成TPE的寵物美容的第100個座標點（25.020039, 121.7001374）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第101個座標點（25.020039, 121.7349249）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第102個座標點（25.020039, 121.7697123）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第103個座標點（25.020039, 121.8044998）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第104個座標點（25.020039, 121.8392872）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第105個座標點（25.020039, 121.8740746）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第106個座標點（25.020039, 121.9088621）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第107個座標點（25.020039, 121.9436495）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第108個座標點（25.020039, 121.978437）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第109個座標點（25.0515705, 121.4218379）的搜尋，共有40筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第110個座標點（25.0515705, 121.4566253）的搜尋，共有57筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第111個座標點（25.0515705, 121.4914128）的搜尋，共有39筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第112個座標點（25.0515705, 121.6305625）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第113個座標點（25.0515705, 121.66535）的搜尋，共有39筆店家資料
# 完成TPE的寵物美容的第114個座標點（25.0515705, 121.7001374）的搜尋，共有13筆店家資料
# 完成TPE的寵物美容的第115個座標點（25.0515705, 121.7349249）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第116個座標點（25.0515705, 121.7697123）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第117個座標點（25.0515705, 121.8044998）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第118個座標點（25.0515705, 121.8392872）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第119個座標點（25.0515705, 121.8740746）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第120個座標點（25.0515705, 121.9088621）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第121個座標點（25.083102, 121.352263）的搜尋，共有40筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第122個座標點（25.083102, 121.3870504）的搜尋，共有49筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第123個座標點（25.083102, 121.4218379）的搜尋，共有31筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第124個座標點（25.083102, 121.4566253）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第125個座標點（25.083102, 121.4914128）的搜尋，共有59筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第126個座標點（25.083102, 121.6305625）的搜尋，共有40筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第127個座標點（25.083102, 121.66535）的搜尋，共有47筆店家資料
# 完成TPE的寵物美容的第128個座標點（25.083102, 121.7697123）的搜尋，共有11筆店家資料
# 完成TPE的寵物美容的第129個座標點（25.083102, 121.8044998）的搜尋，共有4筆店家資料
# 完成TPE的寵物美容的第130個座標點（25.083102, 121.8392872）的搜尋，共有5筆店家資料
# 完成TPE的寵物美容的第131個座標點（25.083102, 121.8740746）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第132個座標點（25.083102, 121.9088621）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第133個座標點（25.1146335, 121.3174755）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第134個座標點（25.1146335, 121.352263）的搜尋，共有7筆店家資料
# 完成TPE的寵物美容的第135個座標點（25.1146335, 121.3870504）的搜尋，共有7筆店家資料
# 完成TPE的寵物美容的第136個座標點（25.1146335, 121.4218379）的搜尋，共有19筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第137個座標點（25.1146335, 121.4566253）的搜尋，共有35筆店家資料
# 完成TPE的寵物美容的第138個座標點（25.1146335, 121.6305625）的搜尋，共有3筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TPE的寵物美容的第139個座標點（25.1146335, 121.7697123）的搜尋，共有45筆店家資料
# 完成TPE的寵物美容的第140個座標點（25.1146335, 121.8044998）的搜尋，共有9筆店家資料
# 完成TPE的寵物美容的第141個座標點（25.1146335, 121.8392872）的搜尋，共有6筆店家資料
# 完成TPE的寵物美容的第142個座標點（25.1146335, 121.8740746）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第143個座標點（25.1146335, 121.9088621）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第144個座標點（25.1461651, 121.3870504）的搜尋，共有4筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第145個座標點（25.1461651, 121.4218379）的搜尋，共有24筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第146個座標點（25.1461651, 121.4566253）的搜尋，共有31筆店家資料
# 完成TPE的寵物美容的第147個座標點（25.1461651, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第148個座標點（25.1461651, 121.6305625）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第149個座標點（25.1776966, 121.4218379）的搜尋，共有35筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第150個座標點（25.1776966, 121.4566253）的搜尋，共有40筆店家資料
# 完成TPE的寵物美容的第151個座標點（25.1776966, 121.4914128）的搜尋，共有5筆店家資料
# 完成TPE的寵物美容的第152個座標點（25.1776966, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第153個座標點（25.1776966, 121.6305625）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第154個座標點（25.1776966, 121.66535）的搜尋，共有1筆店家資料
# 完成TPE的寵物美容的第155個座標點（25.1776966, 121.7001374）的搜尋，共有4筆店家資料
# 正在取得第2頁資訊...
# 完成TPE的寵物美容的第156個座標點（25.2092281, 121.4566253）的搜尋，共有25筆店家資料
# 完成TPE的寵物美容的第157個座標點（25.2092281, 121.4914128）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第158個座標點（25.2092281, 121.5262002）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第159個座標點（25.2092281, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第160個座標點（25.2092281, 121.6305625）的搜尋，共有3筆店家資料
# 完成TPE的寵物美容的第161個座標點（25.2407597, 121.4566253）的搜尋，共有2筆店家資料
# 完成TPE的寵物美容的第162個座標點（25.2407597, 121.4914128）的搜尋，共有4筆店家資料
# 完成TPE的寵物美容的第163個座標點（25.2407597, 121.5262002）的搜尋，共有3筆店家資料
# 完成TPE的寵物美容的第164個座標點（25.2407597, 121.5609876）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第165個座標點（25.2407597, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第166個座標點（25.2407597, 121.6305625）的搜尋，共有4筆店家資料
# 完成TPE的寵物美容的第167個座標點（25.2722912, 121.4914128）的搜尋，共有4筆店家資料
# 完成TPE的寵物美容的第168個座標點（25.2722912, 121.5262002）的搜尋，共有3筆店家資料
# 完成TPE的寵物美容的第169個座標點（25.2722912, 121.5609876）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容的第170個座標點（25.2722912, 121.5957751）的搜尋，共有0筆店家資料
# 完成TPE的寵物美容資料搜尋，總共搜尋171個座標點
# 已完成TPE資料儲存
# 開始搜尋TYU的寵物美容資料
# lat個數：18
# lon個數：15
# 座標點個數：270
# 完成TYU的寵物美容的第1個座標點（24.6179873, 121.3642864）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第2個座標點（24.6179873, 121.3990367）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第3個座標點（24.6495188, 121.3642864）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第4個座標點（24.6495188, 121.3990367）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第5個座標點（24.6495188, 121.433787）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第6個座標點（24.6810503, 121.3642864）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第7個座標點（24.6810503, 121.3990367）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第8個座標點（24.6810503, 121.433787）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第9個座標點（24.6810503, 121.4685373）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第10個座標點（24.7125819, 121.3295361）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第11個座標點（24.7125819, 121.3642864）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第12個座標點（24.7125819, 121.3990367）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第13個座標點（24.7125819, 121.433787）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第14個座標點（24.7441134, 121.3295361）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第15個座標點（24.7441134, 121.3642864）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第16個座標點（24.7441134, 121.3990367）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第17個座標點（24.7756449, 121.2947858）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第18個座標點（24.7756449, 121.3295361）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第19個座標點（24.7756449, 121.3642864）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第20個座標點（24.7756449, 121.3990367）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第21個座標點（24.7756449, 121.433787）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第22個座標點（24.8071765, 121.2252852）的搜尋，共有2筆店家資料
# 完成TYU的寵物美容的第23個座標點（24.8071765, 121.2600355）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第24個座標點（24.8071765, 121.2947858）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第25個座標點（24.8071765, 121.3295361）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第26個座標點（24.8071765, 121.3642864）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第27個座標點（24.8071765, 121.3990367）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第28個座標點（24.8071765, 121.433787）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第29個座標點（24.838708, 121.1905349）的搜尋，共有13筆店家資料
# 完成TYU的寵物美容的第30個座標點（24.838708, 121.2252852）的搜尋，共有17筆店家資料
# 完成TYU的寵物美容的第31個座標點（24.838708, 121.2600355）的搜尋，共有4筆店家資料
# 完成TYU的寵物美容的第32個座標點（24.838708, 121.2947858）的搜尋，共有1筆店家資料
# 完成TYU的寵物美容的第33個座標點（24.838708, 121.3295361）的搜尋，共有1筆店家資料
# 完成TYU的寵物美容的第34個座標點（24.838708, 121.3990367）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第35個座標點（24.8702395, 121.1905349）的搜尋，共有19筆店家資料
# 完成TYU的寵物美容的第36個座標點（24.8702395, 121.2252852）的搜尋，共有20筆店家資料
# 完成TYU的寵物美容的第37個座標點（24.8702395, 121.2600355）的搜尋，共有9筆店家資料
# 完成TYU的寵物美容的第38個座標點（24.8702395, 121.2947858）的搜尋，共有8筆店家資料
# 完成TYU的寵物美容的第39個座標點（24.8702395, 121.3295361）的搜尋，共有2筆店家資料
# 完成TYU的寵物美容的第40個座標點（24.901771, 121.086284）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第41個座標點（24.901771, 121.1210343）的搜尋，共有10筆店家資料
# 正在取得第2頁資訊...
# 完成TYU的寵物美容的第42個座標點（24.901771, 121.1557846）的搜尋，共有25筆店家資料
# 正在取得第2頁資訊...
# 完成TYU的寵物美容的第43個座標點（24.901771, 121.1905349）的搜尋，共有31筆店家資料
# 正在取得第2頁資訊...
# 完成TYU的寵物美容的第44個座標點（24.901771, 121.2252852）的搜尋，共有26筆店家資料
# 正在取得第2頁資訊...
# 完成TYU的寵物美容的第45個座標點（24.901771, 121.2600355）的搜尋，共有30筆店家資料
# 完成TYU的寵物美容的第46個座標點（24.901771, 121.2947858）的搜尋，共有20筆店家資料
# 完成TYU的寵物美容的第47個座標點（24.9333026, 121.086284）的搜尋，共有1筆店家資料
# 完成TYU的寵物美容的第48個座標點（24.9333026, 121.1210343）的搜尋，共有11筆店家資料
# 正在取得第2頁資訊...
# 完成TYU的寵物美容的第49個座標點（24.9333026, 121.1557846）的搜尋，共有29筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第50個座標點（24.9333026, 121.1905349）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第51個座標點（24.9333026, 121.2252852）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第52個座標點（24.9333026, 121.2600355）的搜尋，共有59筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第53個座標點（24.9333026, 121.2947858）的搜尋，共有44筆店家資料
# 完成TYU的寵物美容的第54個座標點（24.9648341, 121.0167833）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第55個座標點（24.9648341, 121.0515336）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第56個座標點（24.9648341, 121.086284）的搜尋，共有3筆店家資料
# 完成TYU的寵物美容的第57個座標點（24.9648341, 121.1210343）的搜尋，共有4筆店家資料
# 完成TYU的寵物美容的第58個座標點（24.9648341, 121.1557846）的搜尋，共有5筆店家資料
# 正在取得第2頁資訊...
# 完成TYU的寵物美容的第59個座標點（24.9648341, 121.1905349）的搜尋，共有32筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第60個座標點（24.9648341, 121.2252852）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第61個座標點（24.9648341, 121.2600355）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第62個座標點（24.9648341, 121.2947858）的搜尋，共有60筆店家資料
# 完成TYU的寵物美容的第63個座標點（24.9963656, 121.0167833）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第64個座標點（24.9963656, 121.0515336）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容的第65個座標點（24.9963656, 121.086284）的搜尋，共有4筆店家資料
# 完成TYU的寵物美容的第66個座標點（24.9963656, 121.1210343）的搜尋，共有3筆店家資料
# 完成TYU的寵物美容的第67個座標點（24.9963656, 121.1557846）的搜尋，共有2筆店家資料
# 完成TYU的寵物美容的第68個座標點（24.9963656, 121.1905349）的搜尋，共有18筆店家資料
# 正在取得第2頁資訊...
# 完成TYU的寵物美容的第69個座標點（24.9963656, 121.2252852）的搜尋，共有37筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第70個座標點（24.9963656, 121.2600355）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第71個座標點（24.9963656, 121.2947858）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第72個座標點（24.9963656, 121.3295361）的搜尋，共有60筆店家資料
# 完成TYU的寵物美容的第73個座標點（24.9963656, 121.3642864）的搜尋，共有10筆店家資料
# 完成TYU的寵物美容的第74個座標點（25.0278972, 121.0515336）的搜尋，共有1筆店家資料
# 完成TYU的寵物美容的第75個座標點（25.0278972, 121.086284）的搜尋，共有2筆店家資料
# 完成TYU的寵物美容的第76個座標點（25.0278972, 121.1210343）的搜尋，共有7筆店家資料
# 完成TYU的寵物美容的第77個座標點（25.0278972, 121.1557846）的搜尋，共有9筆店家資料
# 完成TYU的寵物美容的第78個座標點（25.0278972, 121.1905349）的搜尋，共有17筆店家資料
# 完成TYU的寵物美容的第79個座標點（25.0278972, 121.2252852）的搜尋，共有17筆店家資料
# 正在取得第2頁資訊...
# 完成TYU的寵物美容的第80個座標點（25.0278972, 121.2600355）的搜尋，共有38筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第81個座標點（25.0278972, 121.2947858）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第82個座標點（25.0278972, 121.3295361）的搜尋，共有54筆店家資料
# 完成TYU的寵物美容的第83個座標點（25.0278972, 121.3642864）的搜尋，共有15筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第84個座標點（25.0278972, 121.3990367）的搜尋，共有47筆店家資料
# 完成TYU的寵物美容的第85個座標點（25.0594287, 121.1210343）的搜尋，共有6筆店家資料
# 完成TYU的寵物美容的第86個座標點（25.0594287, 121.1557846）的搜尋，共有7筆店家資料
# 完成TYU的寵物美容的第87個座標點（25.0594287, 121.1905349）的搜尋，共有12筆店家資料
# 完成TYU的寵物美容的第88個座標點（25.0594287, 121.2252852）的搜尋，共有11筆店家資料
# 完成TYU的寵物美容的第89個座標點（25.0594287, 121.2600355）的搜尋，共有14筆店家資料
# 完成TYU的寵物美容的第90個座標點（25.0594287, 121.2947858）的搜尋，共有17筆店家資料
# 完成TYU的寵物美容的第91個座標點（25.0594287, 121.3295361）的搜尋，共有19筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TYU的寵物美容的第92個座標點（25.0594287, 121.3642864）的搜尋，共有51筆店家資料
# 完成TYU的寵物美容的第93個座標點（25.0909602, 121.1905349）的搜尋，共有10筆店家資料
# 完成TYU的寵物美容的第94個座標點（25.0909602, 121.2252852）的搜尋，共有10筆店家資料
# 完成TYU的寵物美容的第95個座標點（25.0909602, 121.2600355）的搜尋，共有1筆店家資料
# 完成TYU的寵物美容的第96個座標點（25.0909602, 121.2947858）的搜尋，共有1筆店家資料
# 完成TYU的寵物美容的第97個座標點（25.1224918, 121.2600355）的搜尋，共有0筆店家資料
# 完成TYU的寵物美容資料搜尋，總共搜尋98個座標點
# 已完成TYU資料儲存
# 開始搜尋TCH的寵物美容資料
# lat個數：15
# lon個數：29
# 座標點個數：435
# 完成TCH的寵物美容的第1個座標點（24.0300873, 120.6294343）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第2個座標點（24.0300873, 120.6640092）的搜尋，共有6筆店家資料
# 完成TCH的寵物美容的第3個座標點（24.0300873, 120.6985841）的搜尋，共有5筆店家資料
# 完成TCH的寵物美容的第4個座標點（24.0300873, 120.733159）的搜尋，共有2筆店家資料
# 完成TCH的寵物美容的第5個座標點（24.0300873, 120.767734）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第6個座標點（24.0616188, 120.6294343）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第7個座標點（24.0616188, 120.6640092）的搜尋，共有10筆店家資料
# 完成TCH的寵物美容的第8個座標點（24.0616188, 120.6985841）的搜尋，共有14筆店家資料
# 完成TCH的寵物美容的第9個座標點（24.0616188, 120.733159）的搜尋，共有9筆店家資料
# 完成TCH的寵物美容的第10個座標點（24.0616188, 120.767734）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第11個座標點（24.0616188, 120.8023089）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第12個座標點（24.0931503, 120.6294343）的搜尋，共有25筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第13個座標點（24.0931503, 120.6640092）的搜尋，共有53筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第14個座標點（24.0931503, 120.6985841）的搜尋，共有56筆店家資料
# 完成TCH的寵物美容的第15個座標點（24.0931503, 120.733159）的搜尋，共有18筆店家資料
# 完成TCH的寵物美容的第16個座標點（24.0931503, 120.767734）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第17個座標點（24.0931503, 120.8023089）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第18個座標點（24.1246819, 120.5602844）的搜尋，共有6筆店家資料
# 完成TCH的寵物美容的第19個座標點（24.1246819, 120.5948593）的搜尋，共有12筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第20個座標點（24.1246819, 120.6294343）的搜尋，共有58筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第21個座標點（24.1246819, 120.6640092）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第22個座標點（24.1246819, 120.6985841）的搜尋，共有40筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第23個座標點（24.1246819, 120.733159）的搜尋，共有28筆店家資料
# 完成TCH的寵物美容的第24個座標點（24.1246819, 120.767734）的搜尋，共有2筆店家資料
# 完成TCH的寵物美容的第25個座標點（24.1246819, 120.8023089）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第26個座標點（24.1246819, 120.8368838）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第27個座標點（24.1246819, 120.8714587）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第28個座標點（24.1246819, 120.9060337）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第29個座標點（24.1246819, 120.9406086）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第30個座標點（24.1246819, 120.9751835）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第31個座標點（24.1562134, 120.5257095）的搜尋，共有9筆店家資料
# 完成TCH的寵物美容的第32個座標點（24.1562134, 120.5602844）的搜尋，共有11筆店家資料
# 完成TCH的寵物美容的第33個座標點（24.1562134, 120.5948593）的搜尋，共有15筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第34個座標點（24.1562134, 120.6294343）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第35個座標點（24.1562134, 120.6640092）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第36個座標點（24.1562134, 120.6985841）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第37個座標點（24.1562134, 120.733159）的搜尋，共有60筆店家資料
# 完成TCH的寵物美容的第38個座標點（24.1562134, 120.767734）的搜尋，共有5筆店家資料
# 完成TCH的寵物美容的第39個座標點（24.1562134, 120.8023089）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第40個座標點（24.1562134, 120.8368838）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第41個座標點（24.1562134, 120.8714587）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第42個座標點（24.1562134, 120.9060337）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第43個座標點（24.1562134, 120.9406086）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第44個座標點（24.1562134, 120.9751835）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第45個座標點（24.1562134, 121.0097585）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第46個座標點（24.1877449, 120.5257095）的搜尋，共有5筆店家資料
# 完成TCH的寵物美容的第47個座標點（24.1877449, 120.5602844）的搜尋，共有9筆店家資料
# 完成TCH的寵物美容的第48個座標點（24.1877449, 120.5948593）的搜尋，共有18筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第49個座標點（24.1877449, 120.6294343）的搜尋，共有36筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第50個座標點（24.1877449, 120.6640092）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第51個座標點（24.1877449, 120.6985841）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TCH的寵物美容的第52個座標點（24.1877449, 120.733159）的搜尋，共有46筆店家資料
# 完成TCH的寵物美容的第53個座標點（24.1877449, 120.767734）的搜尋，共有4筆店家資料
# 完成TCH的寵物美容的第54個座標點（24.1877449, 120.8023089）的搜尋，共有1筆店家資料
# 完成TCH的寵物美容的第55個座標點（24.1877449, 120.8368838）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第56個座標點（24.1877449, 120.8714587）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第57個座標點（24.1877449, 120.9060337）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第58個座標點（24.1877449, 120.9406086）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第59個座標點（24.1877449, 120.9751835）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第60個座標點（24.1877449, 121.0097585）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第61個座標點（24.1877449, 121.0443334）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第62個座標點（24.1877449, 121.0789083）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第63個座標點（24.2192764, 120.4911346）的搜尋，共有1筆店家資料
# 完成TCH的寵物美容的第64個座標點（24.2192764, 120.5257095）的搜尋，共有15筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第65個座標點（24.2192764, 120.5602844）的搜尋，共有26筆店家資料
# 完成TCH的寵物美容的第66個座標點（24.2192764, 120.5948593）的搜尋，共有17筆店家資料
# 完成TCH的寵物美容的第67個座標點（24.2192764, 120.6294343）的搜尋，共有19筆店家資料
# 完成TCH的寵物美容的第68個座標點（24.2192764, 120.6640092）的搜尋，共有20筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第69個座標點（24.2192764, 120.6985841）的搜尋，共有39筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第70個座標點（24.2192764, 120.733159）的搜尋，共有33筆店家資料
# 完成TCH的寵物美容的第71個座標點（24.2192764, 120.767734）的搜尋，共有3筆店家資料
# 完成TCH的寵物美容的第72個座標點（24.2192764, 120.8023089）的搜尋，共有1筆店家資料
# 完成TCH的寵物美容的第73個座標點（24.2192764, 120.8368838）的搜尋，共有1筆店家資料
# 完成TCH的寵物美容的第74個座標點（24.2192764, 120.8714587）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第75個座標點（24.2192764, 120.9060337）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第76個座標點（24.2192764, 120.9406086）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第77個座標點（24.2192764, 120.9751835）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第78個座標點（24.2192764, 121.0097585）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第79個座標點（24.2192764, 121.0443334）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第80個座標點（24.2192764, 121.0789083）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第81個座標點（24.2192764, 121.1134832）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第82個座標點（24.2192764, 121.1480582）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第83個座標點（24.2192764, 121.1826331）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第84個座標點（24.250808, 120.4911346）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第85個座標點（24.250808, 120.5257095）的搜尋，共有22筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第86個座標點（24.250808, 120.5602844）的搜尋，共有36筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第87個座標點（24.250808, 120.5948593）的搜尋，共有23筆店家資料
# 完成TCH的寵物美容的第88個座標點（24.250808, 120.6294343）的搜尋，共有11筆店家資料
# 完成TCH的寵物美容的第89個座標點（24.250808, 120.6640092）的搜尋，共有15筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第90個座標點（24.250808, 120.6985841）的搜尋，共有30筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第91個座標點（24.250808, 120.733159）的搜尋，共有31筆店家資料
# 完成TCH的寵物美容的第92個座標點（24.250808, 120.767734）的搜尋，共有5筆店家資料
# 完成TCH的寵物美容的第93個座標點（24.250808, 120.8023089）的搜尋，共有5筆店家資料
# 完成TCH的寵物美容的第94個座標點（24.250808, 120.8368838）的搜尋，共有3筆店家資料
# 完成TCH的寵物美容的第95個座標點（24.250808, 120.8714587）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第96個座標點（24.250808, 120.9060337）的搜尋，共有1筆店家資料
# 完成TCH的寵物美容的第97個座標點（24.250808, 120.9406086）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第98個座標點（24.250808, 120.9751835）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第99個座標點（24.250808, 121.0097585）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第100個座標點（24.250808, 121.0443334）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第101個座標點（24.250808, 121.0789083）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第102個座標點（24.250808, 121.1134832）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第103個座標點（24.250808, 121.1480582）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第104個座標點（24.250808, 121.1826331）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第105個座標點（24.250808, 121.217208）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第106個座標點（24.250808, 121.2517829）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第107個座標點（24.250808, 121.2863579）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第108個座標點（24.250808, 121.3209328）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第109個座標點（24.250808, 121.3555077）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第110個座標點（24.2823395, 120.5257095）的搜尋，共有13筆店家資料
# 完成TCH的寵物美容的第111個座標點（24.2823395, 120.5602844）的搜尋，共有20筆店家資料
# 完成TCH的寵物美容的第112個座標點（24.2823395, 120.5948593）的搜尋，共有12筆店家資料
# 完成TCH的寵物美容的第113個座標點（24.2823395, 120.6294343）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第114個座標點（24.2823395, 120.6640092）的搜尋，共有3筆店家資料
# 完成TCH的寵物美容的第115個座標點（24.2823395, 120.6985841）的搜尋，共有20筆店家資料
# 正在取得第2頁資訊...
# 完成TCH的寵物美容的第116個座標點（24.2823395, 120.733159）的搜尋，共有22筆店家資料
# 完成TCH的寵物美容的第117個座標點（24.2823395, 120.767734）的搜尋，共有4筆店家資料
# 完成TCH的寵物美容的第118個座標點（24.2823395, 120.8023089）的搜尋，共有4筆店家資料
# 完成TCH的寵物美容的第119個座標點（24.2823395, 120.8368838）的搜尋，共有3筆店家資料
# 完成TCH的寵物美容的第120個座標點（24.2823395, 120.8714587）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第121個座標點（24.2823395, 120.9060337）的搜尋，共有1筆店家資料
# 完成TCH的寵物美容的第122個座標點（24.2823395, 120.9406086）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第123個座標點（24.2823395, 120.9751835）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第124個座標點（24.2823395, 121.0097585）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第125個座標點（24.2823395, 121.0443334）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第126個座標點（24.2823395, 121.0789083）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第127個座標點（24.2823395, 121.1134832）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第128個座標點（24.2823395, 121.1480582）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第129個座標點（24.2823395, 121.1826331）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第130個座標點（24.2823395, 121.217208）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第131個座標點（24.2823395, 121.2517829）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第132個座標點（24.2823395, 121.2863579）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第133個座標點（24.2823395, 121.3209328）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第134個座標點（24.2823395, 121.3555077）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第135個座標點（24.313871, 120.5257095）的搜尋，共有1筆店家資料
# 完成TCH的寵物美容的第136個座標點（24.313871, 120.5602844）的搜尋，共有2筆店家資料
# 完成TCH的寵物美容的第137個座標點（24.313871, 120.5948593）的搜尋，共有5筆店家資料
# 完成TCH的寵物美容的第138個座標點（24.313871, 120.6294343）的搜尋，共有4筆店家資料
# 完成TCH的寵物美容的第139個座標點（24.313871, 120.6640092）的搜尋，共有4筆店家資料
# 完成TCH的寵物美容的第140個座標點（24.313871, 120.6985841）的搜尋，共有8筆店家資料
# 完成TCH的寵物美容的第141個座標點（24.313871, 120.733159）的搜尋，共有10筆店家資料
# 完成TCH的寵物美容的第142個座標點（24.313871, 120.767734）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第143個座標點（24.313871, 120.8023089）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第144個座標點（24.313871, 120.9406086）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第145個座標點（24.313871, 120.9751835）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第146個座標點（24.313871, 121.0097585）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第147個座標點（24.313871, 121.0789083）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第148個座標點（24.313871, 121.1134832）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第149個座標點（24.313871, 121.1480582）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第150個座標點（24.313871, 121.1826331）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第151個座標點（24.313871, 121.217208）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第152個座標點（24.313871, 121.2517829）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第153個座標點（24.313871, 121.2863579）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第154個座標點（24.313871, 121.3209328）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第155個座標點（24.313871, 121.3555077）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第156個座標點（24.313871, 121.3900827）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第157個座標點（24.313871, 121.4246576）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第158個座標點（24.3454026, 120.5602844）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第159個座標點（24.3454026, 120.5948593）的搜尋，共有9筆店家資料
# 完成TCH的寵物美容的第160個座標點（24.3454026, 120.6294343）的搜尋，共有10筆店家資料
# 完成TCH的寵物美容的第161個座標點（24.3454026, 120.6640092）的搜尋，共有4筆店家資料
# 完成TCH的寵物美容的第162個座標點（24.3454026, 120.6985841）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第163個座標點（24.3454026, 120.733159）的搜尋，共有1筆店家資料
# 完成TCH的寵物美容的第164個座標點（24.3454026, 121.1480582）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第165個座標點（24.3454026, 121.1826331）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第166個座標點（24.3454026, 121.217208）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第167個座標點（24.3454026, 121.2517829）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第168個座標點（24.3454026, 121.2863579）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第169個座標點（24.3454026, 121.3209328）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第170個座標點（24.3454026, 121.3555077）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第171個座標點（24.3454026, 121.3900827）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第172個座標點（24.3454026, 121.4246576）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第173個座標點（24.3769341, 120.5948593）的搜尋，共有9筆店家資料
# 完成TCH的寵物美容的第174個座標點（24.3769341, 120.6294343）的搜尋，共有12筆店家資料
# 完成TCH的寵物美容的第175個座標點（24.3769341, 120.6640092）的搜尋，共有4筆店家資料
# 完成TCH的寵物美容的第176個座標點（24.3769341, 121.1826331）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第177個座標點（24.3769341, 121.217208）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第178個座標點（24.3769341, 121.2517829）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第179個座標點（24.3769341, 121.2863579）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第180個座標點（24.3769341, 121.3209328）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第181個座標點（24.3769341, 121.3555077）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第182個座標點（24.3769341, 121.4246576）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第183個座標點（24.4084656, 120.6294343）的搜尋，共有6筆店家資料
# 完成TCH的寵物美容的第184個座標點（24.4084656, 121.2517829）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第185個座標點（24.4084656, 121.2863579）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第186個座標點（24.4084656, 121.3209328）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容的第187個座標點（24.4399972, 121.3209328）的搜尋，共有0筆店家資料
# 完成TCH的寵物美容資料搜尋，總共搜尋188個座標點
# 已完成TCH資料儲存
# 開始搜尋TNA的寵物美容資料
# lat個數：17
# lon個數：19
# 座標點個數：323
# 完成TNA的寵物美容的第1個座標點（22.9190333, 120.1983774）的搜尋，共有7筆店家資料
# 完成TNA的寵物美容的第2個座標點（22.9190333, 120.2326704）的搜尋，共有7筆店家資料
# 完成TNA的寵物美容的第3個座標點（22.9190333, 120.2669634）的搜尋，共有4筆店家資料
# 完成TNA的寵物美容的第4個座標點（22.9190333, 120.3012564）的搜尋，共有3筆店家資料
# 完成TNA的寵物美容的第5個座標點（22.9190333, 120.3355493）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第6個座標點（22.9190333, 120.3698423）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第7個座標點（22.9190333, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第8個座標點（22.9505649, 120.1983774）的搜尋，共有19筆店家資料
# 正在取得第2頁資訊...
# 完成TNA的寵物美容的第9個座標點（22.9505649, 120.2326704）的搜尋，共有34筆店家資料
# 正在取得第2頁資訊...
# 完成TNA的寵物美容的第10個座標點（22.9505649, 120.2669634）的搜尋，共有26筆店家資料
# 完成TNA的寵物美容的第11個座標點（22.9505649, 120.3012564）的搜尋，共有12筆店家資料
# 完成TNA的寵物美容的第12個座標點（22.9505649, 120.3355493）的搜尋，共有4筆店家資料
# 完成TNA的寵物美容的第13個座標點（22.9505649, 120.3698423）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第14個座標點（22.9505649, 120.4041353）的搜尋，共有0筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第15個座標點（22.9820964, 120.1640844）的搜尋，共有55筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第16個座標點（22.9820964, 120.1983774）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第17個座標點（22.9820964, 120.2326704）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第18個座標點（22.9820964, 120.2669634）的搜尋，共有53筆店家資料
# 完成TNA的寵物美容的第19個座標點（22.9820964, 120.3012564）的搜尋，共有12筆店家資料
# 完成TNA的寵物美容的第20個座標點（22.9820964, 120.3355493）的搜尋，共有4筆店家資料
# 完成TNA的寵物美容的第21個座標點（22.9820964, 120.3698423）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第22個座標點（22.9820964, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第23個座標點（22.9820964, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第24個座標點（23.0136279, 120.1297914）的搜尋，共有4筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第25個座標點（23.0136279, 120.1640844）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第26個座標點（23.0136279, 120.1983774）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第27個座標點（23.0136279, 120.2326704）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第28個座標點（23.0136279, 120.2669634）的搜尋，共有47筆店家資料
# 完成TNA的寵物美容的第29個座標點（23.0136279, 120.3012564）的搜尋，共有7筆店家資料
# 完成TNA的寵物美容的第30個座標點（23.0136279, 120.3355493）的搜尋，共有5筆店家資料
# 完成TNA的寵物美容的第31個座標點（23.0136279, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第32個座標點（23.0136279, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第33個座標點（23.0136279, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第34個座標點（23.0136279, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第35個座標點（23.0451595, 120.0612054）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第36個座標點（23.0451595, 120.0954984）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第37個座標點（23.0451595, 120.1297914）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第38個座標點（23.0451595, 120.1640844）的搜尋，共有17筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第39個座標點（23.0451595, 120.1983774）的搜尋，共有43筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成TNA的寵物美容的第40個座標點（23.0451595, 120.2326704）的搜尋，共有45筆店家資料
# 正在取得第2頁資訊...
# 完成TNA的寵物美容的第41個座標點（23.0451595, 120.2669634）的搜尋，共有31筆店家資料
# 完成TNA的寵物美容的第42個座標點（23.0451595, 120.3012564）的搜尋，共有12筆店家資料
# 完成TNA的寵物美容的第43個座標點（23.0451595, 120.3355493）的搜尋，共有5筆店家資料
# 完成TNA的寵物美容的第44個座標點（23.0451595, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第45個座標點（23.0451595, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第46個座標點（23.0451595, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第47個座標點（23.0451595, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第48個座標點（23.0451595, 120.5070143）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第49個座標點（23.076691, 120.0612054）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第50個座標點（23.076691, 120.0954984）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第51個座標點（23.076691, 120.1297914）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第52個座標點（23.076691, 120.1640844）的搜尋，共有7筆店家資料
# 完成TNA的寵物美容的第53個座標點（23.076691, 120.1983774）的搜尋，共有10筆店家資料
# 完成TNA的寵物美容的第54個座標點（23.076691, 120.2326704）的搜尋，共有4筆店家資料
# 完成TNA的寵物美容的第55個座標點（23.076691, 120.2669634）的搜尋，共有8筆店家資料
# 完成TNA的寵物美容的第56個座標點（23.076691, 120.3012564）的搜尋，共有10筆店家資料
# 完成TNA的寵物美容的第57個座標點（23.076691, 120.3355493）的搜尋，共有3筆店家資料
# 完成TNA的寵物美容的第58個座標點（23.076691, 120.3698423）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第59個座標點（23.076691, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第60個座標點（23.076691, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第61個座標點（23.076691, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第62個座標點（23.076691, 120.5070143）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第63個座標點（23.076691, 120.5413073）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第64個座標點（23.1082225, 120.0612054）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第65個座標點（23.1082225, 120.0954984）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第66個座標點（23.1082225, 120.1297914）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第67個座標點（23.1082225, 120.1640844）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第68個座標點（23.1082225, 120.1983774）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第69個座標點（23.1082225, 120.2326704）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第70個座標點（23.1082225, 120.2669634）的搜尋，共有16筆店家資料
# 完成TNA的寵物美容的第71個座標點（23.1082225, 120.3012564）的搜尋，共有18筆店家資料
# 完成TNA的寵物美容的第72個座標點（23.1082225, 120.3355493）的搜尋，共有8筆店家資料
# 完成TNA的寵物美容的第73個座標點（23.1082225, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第74個座標點（23.1082225, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第75個座標點（23.1082225, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第76個座標點（23.1082225, 120.4727213）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第77個座標點（23.1082225, 120.5070143）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第78個座標點（23.1082225, 120.5413073）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第79個座標點（23.1082225, 120.5756003）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第80個座標點（23.1397541, 120.0612054）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第81個座標點（23.1397541, 120.0954984）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第82個座標點（23.1397541, 120.1297914）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第83個座標點（23.1397541, 120.1640844）的搜尋，共有16筆店家資料
# 完成TNA的寵物美容的第84個座標點（23.1397541, 120.1983774）的搜尋，共有13筆店家資料
# 完成TNA的寵物美容的第85個座標點（23.1397541, 120.2326704）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第86個座標點（23.1397541, 120.2669634）的搜尋，共有10筆店家資料
# 完成TNA的寵物美容的第87個座標點（23.1397541, 120.3012564）的搜尋，共有10筆店家資料
# 完成TNA的寵物美容的第88個座標點（23.1397541, 120.3355493）的搜尋，共有5筆店家資料
# 完成TNA的寵物美容的第89個座標點（23.1397541, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第90個座標點（23.1397541, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第91個座標點（23.1397541, 120.4384283）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第92個座標點（23.1397541, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第93個座標點（23.1397541, 120.5070143）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第94個座標點（23.1397541, 120.5413073）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第95個座標點（23.1397541, 120.5756003）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第96個座標點（23.1712856, 120.0954984）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第97個座標點（23.1712856, 120.1297914）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第98個座標點（23.1712856, 120.1640844）的搜尋，共有16筆店家資料
# 完成TNA的寵物美容的第99個座標點（23.1712856, 120.1983774）的搜尋，共有13筆店家資料
# 完成TNA的寵物美容的第100個座標點（23.1712856, 120.2326704）的搜尋，共有13筆店家資料
# 完成TNA的寵物美容的第101個座標點（23.1712856, 120.2669634）的搜尋，共有14筆店家資料
# 完成TNA的寵物美容的第102個座標點（23.1712856, 120.3012564）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第103個座標點（23.1712856, 120.3355493）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第104個座標點（23.1712856, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第105個座標點（23.1712856, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第106個座標點（23.1712856, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第107個座標點（23.1712856, 120.4727213）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第108個座標點（23.1712856, 120.5070143）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第109個座標點（23.1712856, 120.5413073）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第110個座標點（23.1712856, 120.5756003）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第111個座標點（23.1712856, 120.6098933）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第112個座標點（23.2028171, 120.0954984）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第113個座標點（23.2028171, 120.1297914）的搜尋，共有3筆店家資料
# 完成TNA的寵物美容的第114個座標點（23.2028171, 120.1640844）的搜尋，共有9筆店家資料
# 完成TNA的寵物美容的第115個座標點（23.2028171, 120.1983774）的搜尋，共有11筆店家資料
# 完成TNA的寵物美容的第116個座標點（23.2028171, 120.2326704）的搜尋，共有17筆店家資料
# 完成TNA的寵物美容的第117個座標點（23.2028171, 120.2669634）的搜尋，共有15筆店家資料
# 完成TNA的寵物美容的第118個座標點（23.2028171, 120.3012564）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第119個座標點（23.2028171, 120.3355493）的搜尋，共有4筆店家資料
# 完成TNA的寵物美容的第120個座標點（23.2028171, 120.3698423）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第121個座標點（23.2028171, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第122個座標點（23.2028171, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第123個座標點（23.2028171, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第124個座標點（23.2028171, 120.5070143）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第125個座標點（23.2028171, 120.5413073）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第126個座標點（23.2028171, 120.5756003）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第127個座標點（23.2028171, 120.6098933）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第128個座標點（23.2343487, 120.0954984）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第129個座標點（23.2343487, 120.1297914）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第130個座標點（23.2343487, 120.1640844）的搜尋，共有7筆店家資料
# 完成TNA的寵物美容的第131個座標點（23.2343487, 120.1983774）的搜尋，共有7筆店家資料
# 完成TNA的寵物美容的第132個座標點（23.2343487, 120.2326704）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第133個座標點（23.2343487, 120.2669634）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第134個座標點（23.2343487, 120.3012564）的搜尋，共有3筆店家資料
# 完成TNA的寵物美容的第135個座標點（23.2343487, 120.3355493）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第136個座標點（23.2343487, 120.3698423）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第137個座標點（23.2343487, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第138個座標點（23.2343487, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第139個座標點（23.2343487, 120.4727213）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第140個座標點（23.2343487, 120.5070143）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第141個座標點（23.2658802, 120.0954984）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第142個座標點（23.2658802, 120.1297914）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第143個座標點（23.2658802, 120.1640844）的搜尋，共有8筆店家資料
# 完成TNA的寵物美容的第144個座標點（23.2658802, 120.1983774）的搜尋，共有5筆店家資料
# 完成TNA的寵物美容的第145個座標點（23.2658802, 120.2326704）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第146個座標點（23.2658802, 120.2669634）的搜尋，共有3筆店家資料
# 完成TNA的寵物美容的第147個座標點（23.2658802, 120.3012564）的搜尋，共有2筆店家資料
# 完成TNA的寵物美容的第148個座標點（23.2658802, 120.3355493）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第149個座標點（23.2658802, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第150個座標點（23.2658802, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第151個座標點（23.2658802, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第152個座標點（23.2658802, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第153個座標點（23.2658802, 120.5070143）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第154個座標點（23.2974117, 120.0954984）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第155個座標點（23.2974117, 120.1297914）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第156個座標點（23.2974117, 120.1640844）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第157個座標點（23.2974117, 120.2326704）的搜尋，共有6筆店家資料
# 完成TNA的寵物美容的第158個座標點（23.2974117, 120.2669634）的搜尋，共有5筆店家資料
# 正在取得第2頁資訊...
# 完成TNA的寵物美容的第159個座標點（23.2974117, 120.3012564）的搜尋，共有32筆店家資料
# 正在取得第2頁資訊...
# 完成TNA的寵物美容的第160個座標點（23.2974117, 120.3355493）的搜尋，共有22筆店家資料
# 完成TNA的寵物美容的第161個座標點（23.2974117, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第162個座標點（23.2974117, 120.4041353）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第163個座標點（23.2974117, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第164個座標點（23.2974117, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第165個座標點（23.2974117, 120.5070143）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第166個座標點（23.3289432, 120.1297914）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第167個座標點（23.3289432, 120.2669634）的搜尋，共有10筆店家資料
# 正在取得第2頁資訊...
# 完成TNA的寵物美容的第168個座標點（23.3289432, 120.3012564）的搜尋，共有37筆店家資料
# 正在取得第2頁資訊...
# 完成TNA的寵物美容的第169個座標點（23.3289432, 120.3355493）的搜尋，共有22筆店家資料
# 完成TNA的寵物美容的第170個座標點（23.3289432, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第171個座標點（23.3289432, 120.4041353）的搜尋，共有3筆店家資料
# 完成TNA的寵物美容的第172個座標點（23.3289432, 120.4384283）的搜尋，共有4筆店家資料
# 完成TNA的寵物美容的第173個座標點（23.3289432, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第174個座標點（23.3289432, 120.5070143）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第175個座標點（23.3604748, 120.3012564）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第176個座標點（23.3604748, 120.3355493）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第177個座標點（23.3604748, 120.3698423）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第178個座標點（23.3604748, 120.4041353）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第179個座標點（23.3604748, 120.4384283）的搜尋，共有5筆店家資料
# 完成TNA的寵物美容的第180個座標點（23.3604748, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第181個座標點（23.3604748, 120.5070143）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第182個座標點（23.3920063, 120.3698423）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第183個座標點（23.3920063, 120.4041353）的搜尋，共有1筆店家資料
# 完成TNA的寵物美容的第184個座標點（23.3920063, 120.4384283）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容的第185個座標點（23.3920063, 120.4727213）的搜尋，共有0筆店家資料
# 完成TNA的寵物美容資料搜尋，總共搜尋186個座標點
# 已完成TNA資料儲存
# 開始搜尋KSH的寵物美容資料
# lat個數：416
# lon個數：203
# 座標點個數：84448
# 完成KSH的寵物美容的第1個座標點（22.4794558, 120.4236452）的搜尋，共有17筆店家資料
# 完成KSH的寵物美容的第2個座標點（22.5109873, 120.3577283）的搜尋，共有5筆店家資料
# 完成KSH的寵物美容的第3個座標點（22.5109873, 120.3906868）的搜尋，共有10筆店家資料
# 完成KSH的寵物美容的第4個座標點（22.5425188, 120.3247698）的搜尋，共有8筆店家資料
# 完成KSH的寵物美容的第5個座標點（22.5425188, 120.3577283）的搜尋，共有11筆店家資料
# 完成KSH的寵物美容的第6個座標點（22.5425188, 120.3906868）的搜尋，共有9筆店家資料
# 完成KSH的寵物美容的第7個座標點（22.5425188, 120.4236452）的搜尋，共有3筆店家資料
# 完成KSH的寵物美容的第8個座標點（22.5740504, 120.2918113）的搜尋，共有8筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第9個座標點（22.5740504, 120.3247698）的搜尋，共有44筆店家資料
# 正在取得第2頁資訊...
# 完成KSH的寵物美容的第10個座標點（22.5740504, 120.3577283）的搜尋，共有34筆店家資料
# 完成KSH的寵物美容的第11個座標點（22.5740504, 120.3906868）的搜尋，共有18筆店家資料
# 完成KSH的寵物美容的第12個座標點（22.5740504, 120.4236452）的搜尋，共有4筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第13個座標點（22.6055819, 120.2918113）的搜尋，共有55筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第14個座標點（22.6055819, 120.3247698）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第15個座標點（22.6055819, 120.3577283）的搜尋，共有60筆店家資料
# 完成KSH的寵物美容的第16個座標點（22.6055819, 120.3906868）的搜尋，共有17筆店家資料
# 完成KSH的寵物美容的第17個座標點（22.6055819, 120.4236452）的搜尋，共有9筆店家資料
# 完成KSH的寵物美容的第18個座標點（22.6371134, 120.2588528）的搜尋，共有16筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第19個座標點（22.6371134, 120.2918113）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第20個座標點（22.6371134, 120.3247698）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第21個座標點（22.6371134, 120.3577283）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 完成KSH的寵物美容的第22個座標點（22.6371134, 120.3906868）的搜尋，共有35筆店家資料
# 完成KSH的寵物美容的第23個座標點（22.6371134, 120.4236452）的搜尋，共有9筆店家資料
# 完成KSH的寵物美容的第24個座標點（22.668645, 120.2588528）的搜尋，共有14筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第25個座標點（22.668645, 120.2918113）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第26個座標點（22.668645, 120.3247698）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 完成KSH的寵物美容的第27個座標點（22.668645, 120.3577283）的搜尋，共有38筆店家資料
# 完成KSH的寵物美容的第28個座標點（22.668645, 120.3906868）的搜尋，共有14筆店家資料
# 完成KSH的寵物美容的第29個座標點（22.668645, 120.4236452）的搜尋，共有2筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第30個座標點（22.7001765, 120.2918113）的搜尋，共有60筆店家資料
# 正在取得第2頁資訊...
# 正在取得第3頁資訊...
# 完成KSH的寵物美容的第31個座標點（22.7001765, 120.3247698）的搜尋，共有60筆店家資料
# 完成KSH的寵物美容的第32個座標點（22.7001765, 120.3577283）的搜尋，共有20筆店家資料
# 完成KSH的寵物美容的第33個座標點（22.7001765, 120.3906868）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第34個座標點（22.7001765, 120.4236452）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第35個座標點（22.731708, 120.2588528）的搜尋，共有16筆店家資料
# 正在取得第2頁資訊...
# 完成KSH的寵物美容的第36個座標點（22.731708, 120.2918113）的搜尋，共有39筆店家資料
# 正在取得第2頁資訊...
# 完成KSH的寵物美容的第37個座標點（22.731708, 120.3247698）的搜尋，共有40筆店家資料
# 完成KSH的寵物美容的第38個座標點（22.731708, 120.3577283）的搜尋，共有19筆店家資料
# 完成KSH的寵物美容的第39個座標點（22.731708, 120.3906868）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第40個座標點（22.731708, 120.4236452）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第41個座標點（22.7632396, 120.2588528）的搜尋，共有11筆店家資料
# 完成KSH的寵物美容的第42個座標點（22.7632396, 120.2918113）的搜尋，共有15筆店家資料
# 正在取得第2頁資訊...
# 完成KSH的寵物美容的第43個座標點（22.7632396, 120.3247698）的搜尋，共有29筆店家資料
# 完成KSH的寵物美容的第44個座標點（22.7632396, 120.3577283）的搜尋，共有20筆店家資料
# 完成KSH的寵物美容的第45個座標點（22.7632396, 120.3906868）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第46個座標點（22.7632396, 120.4236452）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第47個座標點（22.7947711, 120.2258943）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第48個座標點（22.7947711, 120.2588528）的搜尋，共有7筆店家資料
# 完成KSH的寵物美容的第49個座標點（22.7947711, 120.2918113）的搜尋，共有19筆店家資料
# 完成KSH的寵物美容的第50個座標點（22.7947711, 120.3247698）的搜尋，共有16筆店家資料
# 完成KSH的寵物美容的第51個座標點（22.7947711, 120.3577283）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第52個座標點（22.7947711, 120.3906868）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第53個座標點（22.7947711, 120.4236452）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第54個座標點（22.7947711, 120.4566037）的搜尋，共有3筆店家資料
# 完成KSH的寵物美容的第55個座標點（22.8263026, 120.2258943）的搜尋，共有2筆店家資料
# 完成KSH的寵物美容的第56個座標點（22.8263026, 120.2588528）的搜尋，共有5筆店家資料
# 完成KSH的寵物美容的第57個座標點（22.8263026, 120.2918113）的搜尋，共有13筆店家資料
# 完成KSH的寵物美容的第58個座標點（22.8263026, 120.3247698）的搜尋，共有9筆店家資料
# 完成KSH的寵物美容的第59個座標點（22.8263026, 120.3577283）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第60個座標點（22.8263026, 120.3906868）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第61個座標點（22.8263026, 120.4236452）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第62個座標點（22.8263026, 120.4566037）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第63個座標點（22.8578341, 120.1929358）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第64個座標點（22.8578341, 120.2258943）的搜尋，共有5筆店家資料
# 完成KSH的寵物美容的第65個座標點（22.8578341, 120.2588528）的搜尋，共有6筆店家資料
# 完成KSH的寵物美容的第66個座標點（22.8578341, 120.2918113）的搜尋，共有7筆店家資料
# 完成KSH的寵物美容的第67個座標點（22.8578341, 120.3247698）的搜尋，共有4筆店家資料
# 完成KSH的寵物美容的第68個座標點（22.8578341, 120.3577283）的搜尋，共有3筆店家資料
# 完成KSH的寵物美容的第69個座標點（22.8578341, 120.3906868）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第70個座標點（22.8578341, 120.4236452）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第71個座標點（22.8578341, 120.4566037）的搜尋，共有5筆店家資料
# 完成KSH的寵物美容的第72個座標點（22.8578341, 120.4895622）的搜尋，共有7筆店家資料
# 完成KSH的寵物美容的第73個座標點（22.8578341, 120.5225207）的搜尋，共有4筆店家資料
# 完成KSH的寵物美容的第74個座標點（22.8578341, 120.5554792）的搜尋，共有3筆店家資料
# 完成KSH的寵物美容的第75個座標點（22.8578341, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第76個座標點（22.8578341, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第77個座標點（22.8893657, 120.1929358）的搜尋，共有6筆店家資料
# 完成KSH的寵物美容的第78個座標點（22.8893657, 120.2258943）的搜尋，共有6筆店家資料
# 完成KSH的寵物美容的第79個座標點（22.8893657, 120.2588528）的搜尋，共有9筆店家資料
# 完成KSH的寵物美容的第80個座標點（22.8893657, 120.2918113）的搜尋，共有6筆店家資料
# 完成KSH的寵物美容的第81個座標點（22.8893657, 120.3247698）的搜尋，共有4筆店家資料
# 完成KSH的寵物美容的第82個座標點（22.8893657, 120.3577283）的搜尋，共有3筆店家資料
# 完成KSH的寵物美容的第83個座標點（22.8893657, 120.3906868）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第84個座標點（22.8893657, 120.4236452）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第85個座標點（22.8893657, 120.4566037）的搜尋，共有5筆店家資料
# 完成KSH的寵物美容的第86個座標點（22.8893657, 120.4895622）的搜尋，共有11筆店家資料
# 完成KSH的寵物美容的第87個座標點（22.8893657, 120.5225207）的搜尋，共有5筆店家資料
# 完成KSH的寵物美容的第88個座標點（22.8893657, 120.5554792）的搜尋，共有7筆店家資料
# 完成KSH的寵物美容的第89個座標點（22.8893657, 120.5884377）的搜尋，共有2筆店家資料
# 完成KSH的寵物美容的第90個座標點（22.8893657, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第91個座標點（22.8893657, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第92個座標點（22.8893657, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第93個座標點（22.8893657, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第94個座標點（22.8893657, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第95個座標點（22.8893657, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第96個座標點（22.8893657, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第97個座標點（22.9208972, 120.1929358）的搜尋，共有7筆店家資料
# 完成KSH的寵物美容的第98個座標點（22.9208972, 120.3906868）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第99個座標點（22.9208972, 120.4236452）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第100個座標點（22.9208972, 120.4566037）的搜尋，共有6筆店家資料
# 完成KSH的寵物美容的第101個座標點（22.9208972, 120.4895622）的搜尋，共有6筆店家資料
# 完成KSH的寵物美容的第102個座標點（22.9208972, 120.5225207）的搜尋，共有3筆店家資料
# 完成KSH的寵物美容的第103個座標點（22.9208972, 120.5554792）的搜尋，共有7筆店家資料
# 完成KSH的寵物美容的第104個座標點（22.9208972, 120.5884377）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第105個座標點（22.9208972, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第106個座標點（22.9208972, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第107個座標點（22.9208972, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第108個座標點（22.9208972, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第109個座標點（22.9208972, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第110個座標點（22.9208972, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第111個座標點（22.9208972, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第112個座標點（22.9524287, 120.4566037）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第113個座標點（22.9524287, 120.4895622）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第114個座標點（22.9524287, 120.5225207）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第115個座標點（22.9524287, 120.5554792）的搜尋，共有2筆店家資料
# 完成KSH的寵物美容的第116個座標點（22.9524287, 120.5884377）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第117個座標點（22.9524287, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第118個座標點（22.9524287, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第119個座標點（22.9524287, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第120個座標點（22.9524287, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第121個座標點（22.9524287, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第122個座標點（22.9524287, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第123個座標點（22.9524287, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第124個座標點（22.9839603, 120.4566037）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第125個座標點（22.9839603, 120.4895622）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第126個座標點（22.9839603, 120.5225207）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第127個座標點（22.9839603, 120.5554792）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第128個座標點（22.9839603, 120.5884377）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第129個座標點（22.9839603, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第130個座標點（22.9839603, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第131個座標點（22.9839603, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第132個座標點（22.9839603, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第133個座標點（22.9839603, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第134個座標點（22.9839603, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第135個座標點（22.9839603, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第136個座標點（23.0154918, 120.4895622）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第137個座標點（23.0154918, 120.5225207）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第138個座標點（23.0154918, 120.5554792）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第139個座標點（23.0154918, 120.5884377）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第140個座標點（23.0154918, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第141個座標點（23.0154918, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第142個座標點（23.0154918, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第143個座標點（23.0154918, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第144個座標點（23.0154918, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第145個座標點（23.0154918, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第146個座標點（23.0154918, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第147個座標點（23.0154918, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第148個座標點（23.0470233, 120.5554792）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第149個座標點（23.0470233, 120.5884377）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第150個座標點（23.0470233, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第151個座標點（23.0470233, 120.6543547）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第152個座標點（23.0470233, 120.6873132）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第153個座標點（23.0470233, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第154個座標點（23.0470233, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第155個座標點（23.0470233, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第156個座標點（23.0470233, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第157個座標點（23.0470233, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第158個座標點（23.0785549, 120.5884377）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第159個座標點（23.0785549, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第160個座標點（23.0785549, 120.6543547）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第161個座標點（23.0785549, 120.6873132）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第162個座標點（23.0785549, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第163個座標點（23.0785549, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第164個座標點（23.0785549, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第165個座標點（23.0785549, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第166個座標點（23.0785549, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第167個座標點（23.1100864, 120.5884377）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第168個座標點（23.1100864, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第169個座標點（23.1100864, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第170個座標點（23.1100864, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第171個座標點（23.1100864, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第172個座標點（23.1100864, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第173個座標點（23.1100864, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第174個座標點（23.1100864, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第175個座標點（23.1100864, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第176個座標點（23.1100864, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第177個座標點（23.1416179, 120.6213962）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第178個座標點（23.1416179, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第179個座標點（23.1416179, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第180個座標點（23.1416179, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第181個座標點（23.1416179, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第182個座標點（23.1416179, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第183個座標點（23.1416179, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第184個座標點（23.1416179, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第185個座標點（23.1416179, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第186個座標點（23.1731495, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第187個座標點（23.1731495, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第188個座標點（23.1731495, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第189個座標點（23.1731495, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第190個座標點（23.1731495, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第191個座標點（23.1731495, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第192個座標點（23.1731495, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第193個座標點（23.1731495, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第194個座標點（23.204681, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第195個座標點（23.204681, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第196個座標點（23.204681, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第197個座標點（23.204681, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第198個座標點（23.204681, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第199個座標點（23.204681, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第200個座標點（23.204681, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第201個座標點（23.204681, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第202個座標點（23.2362125, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第203個座標點（23.2362125, 120.6873132）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第204個座標點（23.2362125, 120.7202717）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第205個座標點（23.2362125, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第206個座標點（23.2362125, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第207個座標點（23.2362125, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第208個座標點（23.2362125, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第209個座標點（23.2362125, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第210個座標點（23.2677441, 120.6543547）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第211個座標點（23.2677441, 120.6873132）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第212個座標點（23.2677441, 120.7202717）的搜尋，共有1筆店家資料
# 完成KSH的寵物美容的第213個座標點（23.2677441, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第214個座標點（23.2677441, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第215個座標點（23.2677441, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第216個座標點（23.2677441, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第217個座標點（23.2677441, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第218個座標點（23.2677441, 120.9180226）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第219個座標點（23.2677441, 120.9509811）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第220個座標點（23.2992756, 120.7202717）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第221個座標點（23.2992756, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第222個座標點（23.2992756, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第223個座標點（23.2992756, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第224個座標點（23.2992756, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第225個座標點（23.2992756, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第226個座標點（23.2992756, 120.9180226）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第227個座標點（23.2992756, 120.9509811）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第228個座標點（23.2992756, 120.9839396）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第229個座標點（23.2992756, 121.0168981）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第230個座標點（23.3308071, 120.7532302）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第231個座標點（23.3308071, 120.7861887）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第232個座標點（23.3308071, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第233個座標點（23.3308071, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第234個座標點（23.3308071, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第235個座標點（23.3308071, 120.9180226）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第236個座標點（23.3308071, 120.9509811）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第237個座標點（23.3308071, 120.9839396）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第238個座標點（23.3308071, 121.0168981）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第239個座標點（23.3623387, 120.8191472）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第240個座標點（23.3623387, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第241個座標點（23.3623387, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第242個座標點（23.3623387, 120.9180226）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第243個座標點（23.3623387, 120.9509811）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第244個座標點（23.3623387, 120.9839396）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第245個座標點（23.3938702, 120.8521057）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第246個座標點（23.3938702, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第247個座標點（23.3938702, 120.9180226）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第248個座標點（23.3938702, 120.9509811）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第249個座標點（23.3938702, 120.9839396）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第250個座標點（23.4254017, 120.8850642）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第251個座標點（23.4254017, 120.9180226）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第252個座標點（23.4254017, 120.9509811）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第253個座標點（23.4254017, 120.9839396）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第254個座標點（23.4254017, 121.0168981）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第255個座標點（23.4569332, 120.9180226）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第256個座標點（23.4569332, 120.9509811）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容的第257個座標點（23.4569332, 120.9839396）的搜尋，共有0筆店家資料
# 完成KSH的寵物美容資料搜尋，總共搜尋258個座標點
# 已完成KSH資料儲存
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 118
#     115 meta_name = f"{today}_{keyword_dict[keyword]}_record.csv"
#     116 save_path = os.path.join(meta_save, meta_name)
# --> 118 df_record.to_csv(save_path, index=False)
#     119 df_record.to_sql(name="gmap_record", con=engine, index=False, if_exists="replace")
#
# File c:\Users\add41\AppData\Local\pypoetry\Cache\virtualenvs\tjr103-group-1-project-405QYdcY-py3.11\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\add41\AppData\Local\pypoetry\Cache\virtualenvs\tjr103-group-1-project-405QYdcY-py3.11\Lib\site-packages\pandas\core\generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3978 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3980 formatter = DataFrameFormatter(
#    3981     frame=df,
#    3982     header=header,
#    (...)   3986     decimal=decimal,
#    3987 )
# -> 3989 return DataFrameRenderer(formatter).to_csv(
#    3990     path_or_buf,
#    3991     lineterminator=lineterminator,
#    3992     sep=sep,
#    3993     encoding=encoding,
#    3994     errors=errors,
#    3995     compression=compression,
#    3996     quoting=quoting,
#    3997     columns=columns,
#    3998     index_label=index_label,
#    3999     mode=mode,
#    4000     chunksize=chunksize,
#    4001     quotechar=quotechar,
#    4002     date_format=date_format,
#    4003     doublequote=doublequote,
#    4004     escapechar=escapechar,
#    4005     storage_options=storage_options,
#    4006 )
#
# File c:\Users\add41\AppData\Local\pypoetry\Cache\virtualenvs\tjr103-group-1-project-405QYdcY-py3.11\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\add41\AppData\Local\pypoetry\Cache\virtualenvs\tjr103-group-1-project-405QYdcY-py3.11\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\add41\AppData\Local\pypoetry\Cache\virtualenvs\tjr103-group-1-project-405QYdcY-py3.11\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\add41\AppData\Local\pypoetry\Cache\virtualenvs\tjr103-group-1-project-405QYdcY-py3.11\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'C:\Users\Bevis\Documents\Python_project\sample\output\gmap_search'

# %%
# # E_儲存元數據報告
# from sqlalchemy import create_engine
# from dotenv import load_dotenv

# load_dotenv()

# username = os.getenv("MYSQL_USERNAME")
# password = os.getenv("MYSQL_PASSWORD")
# target_ip = os.getenv("MYSQL_IP")
# target_port = int(os.getenv("MYSQL_PORTT"))
# db_name = os.getenv("MYSQL_DB_NAME")

# engine = create_engine(f"mysql+pymysql://{username}:{password}@{target_ip}:{target_port}/{db_name}")

# sql = "SELECT * FROM gmap_record;"

# df_record = pd.read_sql(sql, engine)

# %%
# # 將本次報告與原有紀錄合併
# df_meta = pd.DataFrame(metadate)
# df_meta["type"] = "lodging"

# df_record = pd.concat([df_record, df_meta], ignore_index=True)
# df_record.drop_duplicates(keep="first", inplace=True)

# %%
# # 按照日期進行儲存
# today = date.today().strftime("%Y%m%d")

# meta_save = r"C:\Users\Bevis\Documents\Python_project\sample\output\gmap_search"
# meta_name = f"{today}_lodging_record.csv"
# save_path = os.path.join(meta_save, meta_name)

# df_record.to_csv(save_path, index=False)
# df_record.to_sql(name="gmap_record", con=engine, index=False, if_exists="replace")
