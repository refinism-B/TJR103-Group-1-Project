# %%
from mods import gmap
import pandas as pd

file = r"C:\Users\Bevis\Documents\Python_project\sample\petboo_fnb_retest.csv"
df = pd.read_csv(file)

df
# Out:
#     city district                             name  \
# 0    台北市      中正區         特有種商行Realguts cafe（藝文咖啡）
# 1    台北市      中正區               Grow Life 靠過來桌遊咖啡廳
# 2    台北市      中正區                            哈燒小食堂
# 3    台北市      中正區                           花漾薇漫餐廳
# 4    台北市      中正區                   別處咖啡 Away cafe
# ..   ...      ...                              ...
# 988  台東縣      東河鄉                          我在玩-玩冰箱
# 989  台東縣      長濱鄉                          巨大少年咖啡館
# 990  台東縣      長濱鄉                             永福野店
# 991  台東縣     太麻里鄉                        太麻里士官長牛肉麵
# 992  台東縣      綠島鄉  綠島甜園夫婦|在地推薦|綠島美食|必吃飛魚|精緻早餐|寵物友善
#
#                            address         phone  rating  rating_count  \
# 0            100台灣台北市中正區臨沂街27巷4-1號  02 2341 1785     4.3        2025.0
# 1       100台灣台北市中正區新生南路一段160巷18-1號  0905 428 741     4.8         569.0
# 2            100台灣台北市中正區寧波西街173-2號  02 2304 7720     4.6         159.0
# ...

# %%
api_key = "AIzaSyCn88oLeZmWBN9GTvxLvoAxlzwo00uW-nQ"

df_sample = df.iloc[150:156]

data = []
for index, row in df_sample.iterrows():
    name = row["name"]
    address = row["address"]
    loc_dict = gmap.get_place_dict(name=name, address=address, api_key=api_key)
    data.append(loc_dict)

df_new = pd.DataFrame(data)

df_new
# Out:
#                                        name                     place_id  \
# 0  微迷野林咖啡店・Wildmii Safari Showroom and Cafe  ChIJLbux2NGpQjQR0uWBQoP7Vw0
# 1        慢步調 咖啡館 | 忠孝復興咖啡廳 | 插座咖啡廳 | 自家烘焙咖啡  ChIJO2MfWderQjQRrSvI-TL_2xA
# 2                      舒服生活 Truffles Living  ChIJ8aBkrs2rQjQROh4u0PycVT8
# 3                              déPLACE 德普雷斯  ChIJ6QYCa8SrQjQRw_p602VwEAM
# 4                        Second Floor 貳樓師大店  ChIJTwJKgoWpQjQReeg0Zb8cNts
# 5                                      祝您行運  ChIJP8lDl92rQjQRzFgaIEFuifw
#
#       business_status                       address       phone  \
# 0  CLOSED_TEMPORARILY        105台灣臺北市松山區復興北路313巷38號  0223620723
# 1         OPERATIONAL     106台灣臺北市大安區忠孝東路三段251巷1弄1號  0227112311
# 2  CLOSED_TEMPORARILY             106台灣臺北市大安區文昌街66號  0227088380
# 3  CLOSED_PERMANENTLY  106台灣臺北市大安區敦化南路一段161巷69弄5號1樓  0227110611
# 4         OPERATIONAL             106台灣臺北市大安區師大路24號  0223656222
# 5         OPERATIONAL    106台灣臺北市大安區羅斯福路三段283巷21弄2號        None
#
# ...

# %%
df_new = pd.DataFrame(data)

df_new
# Out:
#                                        name                     place_id  \
# 0  微迷野林咖啡店・Wildmii Safari Showroom and Cafe  ChIJLbux2NGpQjQR0uWBQoP7Vw0
# 1        慢步調 咖啡館 | 忠孝復興咖啡廳 | 插座咖啡廳 | 自家烘焙咖啡  ChIJO2MfWderQjQRrSvI-TL_2xA
# 2                      舒服生活 Truffles Living  ChIJ8aBkrs2rQjQROh4u0PycVT8
# 3                              déPLACE 德普雷斯  ChIJ6QYCa8SrQjQRw_p602VwEAM
# 4                        Second Floor 貳樓師大店  ChIJTwJKgoWpQjQReeg0Zb8cNts
# 5                                      祝您行運  ChIJP8lDl92rQjQRzFgaIEFuifw
#
#       business_status                       address       phone  \
# 0  CLOSED_TEMPORARILY        105台灣臺北市松山區復興北路313巷38號  0223620723
# 1         OPERATIONAL     106台灣臺北市大安區忠孝東路三段251巷1弄1號  0227112311
# 2  CLOSED_TEMPORARILY             106台灣臺北市大安區文昌街66號  0227088380
# 3  CLOSED_PERMANENTLY  106台灣臺北市大安區敦化南路一段161巷69弄5號1樓  0227110611
# 4         OPERATIONAL             106台灣臺北市大安區師大路24號  0223656222
# 5         OPERATIONAL    106台灣臺北市大安區羅斯福路三段283巷21弄2號        None
#
# ...

# %%
# T_將營業時間轉換成時數的函式

from datetime import time, date, datetime, timedelta

def count_hours(time_str: str):
    """根據時間字串計算小時（字串格式為「xx:xx - xx:xx」）"""
    step2 = time_str.replace("–", "-")
    step3 = step2.split("-")
    step4 = list(map(lambda x: x.strip(), step3))

    fmt = "%H:%M"
    start = datetime.strptime(step4[0], fmt)
    end = datetime.strptime(step4[1], fmt)

    delta = end - start
    if delta.days < 0:
        delta += timedelta(days=1)
    hours = delta.total_seconds() / 3600
    
    return hours


def trans_op_time_to_hours(op_time: list):
    """輸入營業時間list，會逐日計算營業時間並加總後回傳"""
    
    # 若沒有營業時間，則時數直接為0
    if op_time is None:
        op_hours = 0

    # 若有營業時間，則逐日計算時數後相加
    else:
        op_hours = 0
        
        # 營業時間為一週list，採逐日處理
        for day in op_time:
            
            # 使用分隔符號將"星期X"移除
            step1 = day.split(": ")[1].strip()
            
            # 若某日為休息則營業時間為0
            if step1 == "休息":
                hours = 0
            
            else:
                # 若營業時間的字串中含有","表示不只一個營業時段
                # 先切割後再逐段處理
                if "," in day:
                    op_list = step1.split(",")
                    hours = 0
                    for period in op_list:
                        period = period.strip()
                        hours += count_hours(period)
                else:
                    hours = count_hours(step1)
            
            op_hours += hours

    return op_hours

# %%
# T_將每筆資料的營業時間轉換成時數

op_hours_list = []

# 逐筆資料處理
for index, row in df_new.iterrows():
    op_time = row["opening_hours"]

    op_hours = trans_op_time_to_hours(op_time)

    op_hours_list.append(op_hours)

# 所有資料轉換完畢，將整個list新增為df的一個column
df_new["op_hour"] = op_hours_list

# %%
df_new
# Out:
#                                        name                     place_id  \
# 0  微迷野林咖啡店・Wildmii Safari Showroom and Cafe  ChIJLbux2NGpQjQR0uWBQoP7Vw0
# 1        慢步調 咖啡館 | 忠孝復興咖啡廳 | 插座咖啡廳 | 自家烘焙咖啡  ChIJO2MfWderQjQRrSvI-TL_2xA
# 2                      舒服生活 Truffles Living  ChIJ8aBkrs2rQjQROh4u0PycVT8
# 3                              déPLACE 德普雷斯  ChIJ6QYCa8SrQjQRw_p602VwEAM
# 4                        Second Floor 貳樓師大店  ChIJTwJKgoWpQjQReeg0Zb8cNts
# 5                                      祝您行運  ChIJP8lDl92rQjQRzFgaIEFuifw
#
#       business_status                       address       phone  \
# 0  CLOSED_TEMPORARILY        105台灣臺北市松山區復興北路313巷38號  0223620723
# 1         OPERATIONAL     106台灣臺北市大安區忠孝東路三段251巷1弄1號  0227112311
# 2  CLOSED_TEMPORARILY             106台灣臺北市大安區文昌街66號  0227088380
# 3  CLOSED_PERMANENTLY  106台灣臺北市大安區敦化南路一段161巷69弄5號1樓  0227110611
# 4         OPERATIONAL             106台灣臺北市大安區師大路24號  0223656222
# 5         OPERATIONAL    106台灣臺北市大安區羅斯福路三段283巷21弄2號        None
#
# ...
