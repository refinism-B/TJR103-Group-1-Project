# %%
import os
import time
import ast
import re
from datetime import date
import pymysql

import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine
from opencc import OpenCC

from mods import gmap
from mods import pandas_mod as pdm
from mods import date_mod as dtm

# %%
def create_pymysql_connect():
    """
    自動透過pymysql建立連線，回傳conn連線物件。
    所需各項資料請寫入.env檔案中。請勿直接寫於程式中。
    """

    load_dotenv()

    username = os.getenv("MYSQL_USERNAME")
    password = os.getenv("MYSQL_PASSWORD")
    target_ip = os.getenv("MYSQL_IP")
    target_port = int(os.getenv("MYSQL_PORTT"))
    db_name = os.getenv("MYSQL_DB_NAME")

    conn = pymysql.connect(
        host=target_ip,
        port=target_port,
        user=username,
        password=password,
        database=db_name,
        charset='utf8mb4'
    )

    return conn


def E_load_from_sql(table_name: str) -> pd.DataFrame:
    """
    輸入欲查詢的表名table_name，透過pymysql連線資料庫，
    並取得該表後將其轉成dataframe。

    連線所需資訊請寫入.env中，請勿寫入程式中。
    """

    conn = create_pymysql_connect()
    sql = f"SELECT * FROM {table_name}"

    try:
        df = pd.read_sql(sql, conn)
        return df.to_dict(orient='records')

    except Exception as e:
        raise Exception(f"讀取{table_name}表時發生錯誤：{e}")
    

def reassign_id(df, id_col_name, id_str):
    """根據原有最後一筆資料進行自動延續編號
    對於未編號的資料，需要先建立id欄位並且賦予空字串
    df請輸入想要增加編號的df
    id_col_name請輸入id的「欄位名」
    id_str請輸入編號的「前綴字串」"""

    # 先找出原本的id編號（id欄位非空）最大值
    nums = df.loc[df[id_col_name] != "",
                  id_col_name].str.extract(r"(\d+)").astype(int)

    if nums.empty:
        start_num = 1876
    else:
        start_num = nums.max()[0] + 1

    # 計算需要新增的資料數
    empty_id = df[id_col_name] == ""
    empty_id_count = empty_id.sum()

    # 先列出編號list
    new_id = [f"{id_str}{i:04d}" for i in range(
        start_num, start_num + empty_id_count)]

    # 將list放入df欄位
    df.loc[empty_id, id_col_name] = new_id

    return df

# %%
type_id_dict = {
    "寵物美容":"sal",
    "寵物餐廳":"res",
    "寵物用品":"supl"
}

type_file_dict = {
    "寵物美容":"salon",
    "寵物餐廳":"restaurant",
    "寵物用品":"supplies"
}

replace_word_dict = {
    "区":"區",
    "霧峯":"霧峰",
    "中壢市":"中壢區",
    "省":"",
    "萬裏":"萬里",
    "區區":"區"
}

store_type = "寵物用品"

# %%
folder = r"C:\Users\add41\Documents\Data_Engineer\Project\example_data\gmap_full_search\temp"
file = f"{type_file_dict[store_type]}_TPEI_combine.csv"
path = os.path.join(folder, file)

df_main = pd.read_csv(path, dtype={"phone": str})

print(f"資料筆數：{len(df_main)}")
# Out:
# 資料筆數：261

# %%
def remove_data(df, keywords):
    del_idx = []

    for keyword in keywords:
        idx = df[df["name"].str.contains(keyword, na=False)].index
        if len(idx) != 0:
            del_idx.extend(idx)

    del_idx = list(set(del_idx))

    df.drop(index=del_idx, axis=0, inplace=True)
    return df


del_keywords = ["停業", "歇業", "暫停營業", "暫停服務", "停止營業", "停止服務"]
df_main = remove_data(df=df_main, keywords=del_keywords)

# %%
def pre_trans_addres(df, store_type, replace_word_dict):
    """先新增類別欄位，並簡單將地址做簡轉繁、錯別字處理"""

    # 新增類別
    df["category"] = store_type

    # 處理掉不要的欄位
    df.drop(columns=["in_boundary", "update_date"], axis=1, inplace=True)
    df.dropna(subset=["address"], inplace=True)

    # 將評分和評論數補空值為0
    df_main[["rating", "rating_total"]] = df_main[["rating", "rating_total"]].fillna(0)

    # 先將地址全部做簡體轉繁體
    cc = OpenCC("s2t")
    df["address"] = df["address"].apply(cc.convert)

    # 清理一些地址中會出現的錯別字
    for word in replace_word_dict:
        df["address"] = df["address"].str.replace(word, replace_word_dict[word])

    # 先新增市和區的空欄位
    df["city"] = None
    df["district"] = None

    return df


df_main = pre_trans_addres(df_main, store_type, replace_word_dict)

# %%
# 先編寫處理地址的規則
pattern1 = r"([^\d\s]{2}市)([^\d\s]{1,3}區)"
pattern2 = r"灣([^\d\s]{1,2}區)"
pattern3 = r"([^\d\s]{2}區)([^\d\s]{2}市)"

# %%
def first_add_trans(df, pattern):
    """處理第一種情況：正常地址格式"""

    mask1 = df["address"].str.contains(pattern, regex=True, na=False)
    extracted1 = df.loc[mask1, "address"].str.extract(pattern)
    df.loc[mask1, ["city", "district"]] = extracted1.values

    return df

df_main = first_add_trans(df_main, pattern1)
# Out:
# C:\Users\add41\AppData\Local\Temp\ipykernel_14704\644889809.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask1 = df["address"].str.contains(pattern, regex=True, na=False)

# %%
def second_add_trans(df, pattern):
    """處理第二種情況：地址格式倒反"""

    mask3 = df["address"].str.contains(pattern, regex=True, na=False)
    extracted3 = df.loc[mask3, "address"].str.extract(pattern)

    df.loc[mask3, "city"] = extracted3[1].values
    df.loc[mask3, "district"] = extracted3[0].values

    return df

df_main = second_add_trans(df_main, pattern3)
# Out:
# C:\Users\add41\AppData\Local\Temp\ipykernel_14704\1860904253.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask3 = df["address"].str.contains(pattern, regex=True, na=False)

# %%
def third_add_trans(df, pattern):
    """處理第三種狀況：只有區沒有市"""

    mask2 = df["address"].str.contains(pattern, regex=True, na=False)
    extracted2 = df.loc[mask2, "address"].str.extract(pattern)
    df.loc[mask2, "district"] = extracted2[0].values

    return df

df_main = third_add_trans(df_main, pattern2)
# Out:
# C:\Users\add41\AppData\Local\Temp\ipykernel_14704\4062369329.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask2 = df["address"].str.contains(pattern, regex=True, na=False)

# %%
def fourth_add_trans(df, drop_words):
    """清理區中不乾淨的字元"""

    df["district"] = df["district"].str.replace("路竹", "鹿竹")
    pattern4 = "|".join(map(re.escape, drop_words))
    df["district"] = df["district"].str.replace(pattern4, "", regex=True)
    df["district"] = df["district"].str.replace("鹿竹", "路竹")

    return df

drop_words = ["路", "街", "巷", "弄", "段", "道"]
df_main = fourth_add_trans(df_main, drop_words)

# %%
def join_loc_id(df):
    """讀取地區資料，並與店家表join，留下loc id，並將city和district欄位去除"""

    # 讀取地區table
    df_loc_data = E_load_from_sql(table_name="location")
    df_loc = pd.DataFrame(data=df_loc_data)
    df_loc_select = df_loc[["loc_id", "city", "district"]]

    # 進行第一次join，根據市/區合併
    df = df.merge(df_loc_select, how="left", on=["city", "district"])

    # 取出loc id為空、沒有市資料的索引
    miss_loc = df["loc_id"].isna()

    # 如果有，進行第二次join
    if len(miss_loc) != 0:
        df_miss = df[miss_loc].drop(columns="loc_id", axis=1)

        df_miss = df_miss.merge(df_loc_select, how="left", on="district")

        df.loc[miss_loc, "loc_id"] = df_miss["loc_id"].values

    # 移除市區欄位
    df.drop(columns=["city", "district"], axis=1, inplace=True)

    return df

df_main = join_loc_id(df_main)
# Out:
# C:\Users\add41\AppData\Local\Temp\ipykernel_14704\1001074935.py:39: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)

# %%
def join_type_id(df):
    """讀取類別資料，並與店家表join，留下類別id，將類別欄位去除"""

    df_catego_data = E_load_from_sql(table_name="category")
    df_catego = pd.DataFrame(data=df_catego_data)

    df = df.merge(df_catego, how="left",
                            left_on="category", right_on="category_name")
    df.drop(columns=["category_name", "category_eng", "category"], axis=1, inplace=True)

    return df

df_main = join_type_id(df_main)
# Out:
# C:\Users\add41\AppData\Local\Temp\ipykernel_14704\1001074935.py:39: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)

# %%
def add_id(df, type_id_dict, store_type):
    """加上類別id"""

    df["id"] = ""
    df = reassign_id(df, "id", type_id_dict[store_type])

    return df

df_main = add_id(df_main, type_id_dict, store_type)

# %%
def trans_op_hours(df):
    """將營業時間轉為時數"""
    op_hours_list = []
    for index, row in df.iterrows():
        op_time = row["opening_hours"]
        op_hours = dtm.trans_op_time_to_hours(op_time)
        op_hours_list.append(op_hours)

    df["op_hours"] = op_hours_list
    df.drop(columns="opening_hours", axis=1, inplace=True)

    return df

df_main = trans_op_hours(df_main)

# %%
new_col = ["id", 'name', 'buss_status', 'loc_id', 'address', 'phone', "op_hours", 'category_id', 'rating',
           'rating_total', 'newest_review', 'longitude', 'latitude', 'map_url', 'website', 'place_id', 'update_time']

df_main = df_main[new_col]

# %%
today = date.today().strftime("%Y%m%d")

finish_file = f"{today}{type_file_dict[store_type]}_TPEI_finish.csv"
finish_path = os.path.join(folder, finish_file)
df_main.to_csv(finish_path, index=False, encoding="utf-8-sig")

loc_na = df_main[df_main["loc_id"].isna()]

print(f"存檔完成，資料筆數：{len(df_main)}")
print(f"地區缺失資料數：{len(loc_na)}")
# Out:
# 存檔完成，資料筆數：261
# 地區缺失資料數：0

# %%
len(df_main.columns)
# Out:
# 17

# %%
df_main.head(25)
# Out:
#           id                                               name  buss_status  \
# 0   supl1876                                         咕咕G寵物城-木柵店  OPERATIONAL
# 1   supl1877                                            PetPark  OPERATIONAL
# 2   supl1878                                               木星寵物  OPERATIONAL
# 3   supl1879                                            PetPark  OPERATIONAL
# 4   supl1880                                      晶晶寵物店（原金美滿寵物）  OPERATIONAL
# 5   supl1881                                     哈哈窩寵物精品館-北市景興店  OPERATIONAL
# 6   supl1882                                    喜羊羊寵物生活館(北市景興店)  OPERATIONAL
# 7   supl1883                                            豆恩凱寵物沙龍  OPERATIONAL
# 8   supl1884                                           黛希寵物美容沙龍  OPERATIONAL
# 9   supl1885                                             景興動物醫院  OPERATIONAL
# 10  supl1886                                          毛毛窩寵物精品旅館  OPERATIONAL
# 11  supl1887                                            特寵小動物用品  OPERATIONAL
# 12  supl1888                                            大千寵物用品店  OPERATIONAL
# 13  supl1889                                              四足寵物店  OPERATIONAL
# 14  supl1890                                          集寵洗澡間 木柵店  OPERATIONAL
# 15  supl1891                                 金吉利寵物精品店(公館店)(汀州店)  OPERATIONAL
# 16  supl1892                          寵物公園(台北興隆店) - 專業寵物用品&寵物美容  OPERATIONAL
# 17  supl1893                                         日不落寵物店 文山店  OPERATIONAL
# 18  supl1894                                         昆比的家寵物自助澡間  OPERATIONAL
# 19  supl1895                                           喜貓喜狗寵物美容  OPERATIONAL
# 20  supl1896                     寵蝦咪寵物美容住宿/寵物咖啡廳Chongshopme-文山店  OPERATIONAL
# 21  supl1897                                          哈比寵物百貨便利店  OPERATIONAL
# 22  supl1898                                             貓大王寵物店  OPERATIONAL
# 23  supl1899                                         金吉利寵物店-中華店  OPERATIONAL
# 24  supl1900  冠罐寵屋 & 雞2糕（中正汀州店）現烤雞蛋糕｜客製寵糧｜寵物食品｜寵物用品｜寵物選品｜寵物交...  OPERATIONAL
#
#     loc_id                  address       phone  op_hours category_id  rating  \
# 0   TPE008    116臺灣臺北市文山區興隆路四段70-1號  0229398833      70.0           5     4.1
# 1   TPE008  11674臺灣臺北市文山區羅斯福路六段302號  0229317200      63.0           5     4.6
# 2   TPE008     116臺灣臺北市文山區木新路三段226號  0229368099      70.0           5     4.8
# 3   TPE008     116臺灣臺北市文山區木新路三段272號  0229372900      63.0           5     4.4
# 4   TPE008     116臺灣臺北市文山區興隆路三段261號  0222393188      72.0           5     4.3
# 5   TPE008       116臺灣臺北市文山區景興路169號  0229337700      59.5           5     4.2
# 6   TPE008       116臺灣臺北市文山區景興路169號  0229337700      77.0           5     5.0
# 7   TPE008       116臺灣臺北市文山區木新路二段1號  0286612369      54.0           5     4.5
# 8   TPE008      116臺灣臺北市文山區景華街18號1樓  0289319906      60.0           5     4.8
# 9   TPE008        116臺灣臺北市文山區景華街92號  0229330600      60.0           5     4.5
# 10  TPE008        116臺灣臺北市文山區景隆街48號  0229345717      84.0           5     4.7
# 11  TPE008         116臺灣臺北市文山區景興路9號  0286633058      52.5           5     4.2
# 12  TPE008   11619臺灣臺北市文山區木新路三段263號  0229360789      69.0           5     4.5
# 13  TPE008      116臺灣臺北市文山區木新路三段64號  0222347587      45.0           5     5.0
# 14  TPE008      116臺灣臺北市文山區木柵路二段29號  0229393757      45.0           5     4.5
# 15  TPE005     100臺灣臺北市中正區汀州路三段100號  0223657983      80.5           5     4.5
# 16  TPE008     116臺灣臺北市文山區興隆路二段343號  0286632212      77.0           5     4.8
# 17  TPE008     116臺灣臺北市文山區興隆路二段221號  0229319998      52.5           5     4.7
# 18  TPE008   116臺灣臺北市文山區興隆路二段220巷8號  0286637911      60.0           5     5.0
# 19  TPE008  116臺灣臺北市文山區興隆路二段203巷46號  0286638068      63.0           5     2.5
# 20  TPE008     116臺灣臺北市文山區興隆路一段261號  0229331890      54.0           5     4.8
# 21  TPE008    116臺灣臺北市文山區羅斯福路五段246號  0229346286      51.0           5     4.9
# 22  TPE008      116臺灣臺北市文山區興德路42-1號  0229353995      62.5           5     4.6
# 23  TPE005     100臺灣臺北市中正區中華路二段179號  0223043000      77.0           5     4.5
# 24  TPE005     100臺灣臺北市中正區汀州路一段264號  0908679986      46.0           5     4.8
#
#     rating_total newest_review   longitude   latitude  \
# 0          261.0    2025-04-19  121.561562  24.984316
# 1          232.0    2021-05-05  121.539704  24.990713
# 2           64.0    2025-04-28  121.559249  24.981490
# 3          189.0    2025-03-23  121.558347  24.981230
# 4           55.0    2021-04-28  121.558864  24.992368
# 5           68.0    2021-07-06  121.544583  24.993163
# 6            2.0    2024-09-05  121.544539  24.993116
# 7          104.0    2025-02-12  121.570835  24.987609
# 8           77.0    2024-08-30  121.542148  24.994844
# 9          222.0    2025-08-24  121.545716  24.995151
# 10         115.0    2025-09-18  121.544084  24.998570
# 11         493.0    2025-05-15  121.544778  24.998194
# 12          49.0    2024-02-24  121.558206  24.980933
# 13          14.0    2018-06-01  121.563812  24.982549
# 14          85.0    2025-06-22  121.559622  24.988853
# 15        1071.0    2025-01-20  121.532922  25.014403
# 16         530.0    2025-07-20  121.554272  25.001094
# 17          53.0    2024-01-07  121.550337  25.001228
# 18         107.0    2024-10-26  121.552143  25.001069
# 19          11.0    2023-06-22  121.548396  25.002255
# 20          79.0    2025-05-10  121.544274  24.999307
# 21          34.0    2018-08-01  121.538997  25.001202
# 22          58.0    2020-12-06  121.556572  25.001381
# 23         498.0    2025-11-09  121.504262  25.030204
# 24          20.0    2025-08-16  121.511026  25.026868
#
#                                               map_url  \
# 0    https://maps.google.com/?cid=9590099804699171261
# 1     https://maps.google.com/?cid=707242357215644003
# 2      https://maps.google.com/?cid=78979114800680598
# 3     https://maps.google.com/?cid=469218073759243828
# 4   https://maps.google.com/?cid=13521194320155065958
# 5   https://maps.google.com/?cid=10431518333823885977
# 6    https://maps.google.com/?cid=9567540067286104302
# 7   https://maps.google.com/?cid=12388809864078626836
# 8    https://maps.google.com/?cid=9574317886448112929
# 9   https://maps.google.com/?cid=12713671958385079329
# 10  https://maps.google.com/?cid=15749438957578257977
# 11   https://maps.google.com/?cid=9460659268518656747
# 12  https://maps.google.com/?cid=15772604550031396002
# 13  https://maps.google.com/?cid=18265371723232424691
# 14   https://maps.google.com/?cid=8662258059933029995
# 15    https://maps.google.com/?cid=636588536939313408
# 16   https://maps.google.com/?cid=7134106371540621188
# 17  https://maps.google.com/?cid=15450228320596970690
# 18  https://maps.google.com/?cid=17513313313146297292
# 19   https://maps.google.com/?cid=2714794477666972556
# 20   https://maps.google.com/?cid=3482905431822224120
# 21   https://maps.google.com/?cid=1066057005152382848
# 22  https://maps.google.com/?cid=18312387181941423785
# 23   https://maps.google.com/?cid=9629449236451901393
# 24   https://maps.google.com/?cid=4063605764169287202
#
#                                               website  \
# 0                                                 NaN
# 1                          http://www.wonderpet.asia/
# 2                                                 NaN
# 3                         https://www.wonderpet.asia/
# 4                                                 NaN
# 5              https://www.facebook.com/hahahouse107/
# 6                           http://www.cyypet.com.tw/
# 7                                                 NaN
# 8                    https://line.me/R/ti/p/@zfz5058g
# 9                                                 NaN
# 10                                                NaN
# 11                https://www.facebook.com/petlove668
# 12                                                NaN
# 13                                                NaN
# 14                             https://lin.ee/HvYBnTE
# 15      https://m.facebook.com/cold.td/?locale2=zh_TW
# 16                        https://www.wonderpet.asia/
# 17       https://www.facebook.com/RiBuLuoChongWuDian/
# 18  https://www.facebook.com/profile.php?id=615595...
# 19                                                NaN
# 20  https://www.facebook.com/profile.php?id=615514...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                             https://lin.ee/hANCOZT
#
#                        place_id          update_time
# 0   ChIJVVVVVd4BaDQRvRmjO_bgFoU  2025/11/16 17:31:46
# 1   ChIJqaK_YQCqQjQRY8nyPy2h0Ak  2025/11/16 17:31:46
# 2   ChIJaRgNdAwBaDQRlo5eIhaXGAE  2025/11/16 17:31:46
# 3   ChIJ6apPwOABaDQRNN6cIFr_ggY  2025/11/16 17:31:46
# 4   ChIJV_b0xAyqQjQRZj7fh5jupLs  2025/11/16 17:31:46
# 5   ChIJSRm-kAaqQjQRmSKM86cyxJA  2025/11/16 17:31:46
# 6   ChIJj0CozxWrQjQR7rjnDAC7xoQ  2025/11/16 17:31:46
# 7   ChIJ4SSyQHWqQjQRFBBDwu7k7as  2025/11/16 17:31:46
# 8   ChIJfe1t-wOqQjQRIZVoDGTP3oQ  2025/11/16 17:31:46
# 9   ChIJ6Td9tQWqQjQRITRjRkkJcLA  2025/11/16 17:31:46
# 10  ChIJr8ISuASqQjQROYYmrkk_kdo  2025/11/16 17:31:46
# 11  ChIJs_GN3B2qQjQR67oP4XoDS4M  2025/11/16 17:31:46
# 12  ChIJG-f-xuABaDQRosxUe0WM49o  2025/11/16 17:31:46
# 13  ChIJtZl8FN8BaDQR87K75c6ie_0  2025/11/16 17:31:46
# 14  ChIJK-NSNAuqQjQRa5YSl8-FNng  2025/11/16 17:31:46
# 15  ChIJU0w0EoupQjQRAHlazOad1Qg  2025/11/16 17:31:46
# 16  ChIJrw8hpcWrQjQRhJeHYfJvAWM  2025/11/16 17:31:46
# 17  ChIJ_8cn7hCqQjQRwszce8w8atY  2025/11/16 17:31:46
# 18  ChIJe4drdACrQjQRzFs0NqvJC_M  2025/11/16 17:31:46
# 19  ChIJLfG6N9qrQjQRjDOInzHjrCU  2025/11/16 17:31:46
# 20  ChIJ31CkR8yrQjQR-MoKegnEVTA  2025/11/16 17:31:46
# 21  ChIJAQGFOh2qQjQRgK9srjJlyw4  2025/11/16 17:31:46
# 22  ChIJ1yAV9hOqQjQRqf4IaR6rIv4  2025/11/16 17:31:46
# 23  ChIJuzPYNaWpQjQR0T9fwQ-tooU  2025/11/16 17:31:46
# 24  ChIJ3WiZLZapQjQRIkaKoOnTZDg  2025/11/16 17:31:46

# %%
conn = create_pymysql_connect()
cursor = conn.cursor()

df_main = df_main.replace({pd.NA: None, pd.NaT: None})
data = list(df_main.itertuples(index=False, name=None))

sql = f"INSERT INTO {type_file_dict[store_type]} (id, name, buss_status, loc_id, address, phone, op_hours, category_id, rating, rating_total, newest_review, longitude, latitude, map_url, website, place_id, update_time) VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

try:
    cursor.executemany(sql, data)
    conn.commit()
    print("資料寫入資料庫成功！")
except Exception as e:
    print(f"資料寫入資料褲時發生錯誤：{e}")
    conn.rollback()
finally:
    cursor.close()
    conn.close()
# Out:
# 資料寫入資料庫成功！
