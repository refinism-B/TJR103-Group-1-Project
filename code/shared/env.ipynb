# %%
from dotenv import load_dotenv
import os

load_dotenv()

mysql_ip = os.environ.get("MYSQL_IP")
port = os.environ.get("MYSQL_PORTT")

print(f"mysql環境變數：{mysql_ip}\nport：{port}")
# Out:
# mysql環境變數：tpe1.clusters.zeabur.com
# port：20721
